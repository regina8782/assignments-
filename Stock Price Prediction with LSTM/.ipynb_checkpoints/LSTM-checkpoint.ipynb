# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-498991d0-a6bc-4834-91d5-d2cd536d0a87" name="files[]" multiple disabled />
#      <output id="result-498991d0-a6bc-4834-91d5-d2cd536d0a87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 8046_2010_2019.csv to 8046_2010_2019.csv

# %%
files.download('8046_2010_2019.csv')

# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

f=open(r'./8046_2010_2019.csv')  
df=pd.read_csv(f)     
df=df.dropna(axis=0,how='all')  
data=np.array(df[['close']])

print(df.shape[0])
time_step=20      
rnn_unit=10       
batch_size=60     
input_size=1      
output_size=1     
lr=0.0006         
train_X,train_Y=[],[]   
print(len(data)-time_step-1-30)
for i in range(len(data)-time_step-1-30):    
    x=data[i:i+time_step]
    y=data[i+1:i+time_step+1]
    train_X.append(x.tolist())
    train_Y.append(y.tolist())
# print(train_X)
# print(train_Y)

test_x,test_y=[],[]  
for i in range(30):
    x=data[len(data)-30+i-1,np.newaxis]
    test_x.append(x.tolist())
    
for i in range(30):
    y=data[i-30]
    test_y.append(y.tolist())
# print(x)        
# print(test_x)
# print(test_y)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2372
# 2321

# %%
X=tf.placeholder(tf.float32, [None,None,input_size], name='X')    
Y=tf.placeholder(tf.float32, [None,None,output_size], name='Y')   
# keep_prob=tf.placeholder(tf.float32, name='keep_prob')



weights={
         'in':tf.Variable(tf.random_normal([input_size,rnn_unit]) ,name='w_in'),
         'out':tf.Variable(tf.random_normal([rnn_unit,1]) ,name='w_out')
         }
biases={
        'in':tf.Variable(tf.constant(0.1,shape=[rnn_unit]) ,name='b_in'),
        'out':tf.Variable(tf.constant(0.1,shape=[1]) ,name='b_out')
        }

# %%
def lstm(batch_size, time_step, input_size):      
    w_in=weights['in']
    b_in=biases['in']
    input=tf.reshape(X,[-1,input_size])  

    
    input_rnn=tf.nn.relu(tf.matmul(input,w_in)+b_in)  #hidden layer
    print(input)
    print(input_rnn)
    input_rnn=tf.nn.dropout(input_rnn, keep_prob=0.5)
    input_rnn=tf.reshape(input_rnn,[-1,time_step,rnn_unit])  
    cell=tf.nn.rnn_cell.BasicLSTMCell(rnn_unit)
    mlstm_cell = tf.compat.v1.nn.rnn_cell.MultiRNNCell([cell]*3, state_is_tuple = True)  
    init_state=cell.zero_state(batch_size,dtype=tf.float32)
    output_rnn,final_states=tf.nn.dynamic_rnn(cell, input_rnn,initial_state=init_state, dtype=tf.float32)  

    output=tf.reshape(output_rnn,[-1,rnn_unit]) 
    w_out=weights['out']
    b_out=biases['out']
    pred=tf.matmul(output,w_out)+b_out
    print(input_rnn)
    print(w_in)
    return pred,final_states

# %%
#——————————————————training model——————————————————
def train_lstm():
    global batch_size
    pred,_=lstm(batch_size, time_step, input_size)
    print(pred)
    loss=tf.reduce_mean(tf.square(tf.reshape(pred,[-1])-tf.reshape(Y, [-1])))  
    #loss function:MSE(mean square error)
    train_op=tf.train.AdamOptimizer(lr).minimize(loss)
    saver=tf.train.Saver(tf.global_variables())
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(1000):
            step=0
            start=0
            end=start+batch_size
            while(end<len(train_X)):
                _,loss_=sess.run([train_op,loss],feed_dict={X:train_X[start:end],Y:train_Y[start:end]})
                start+=batch_size
                end=start+batch_size
                #每50步保存一次参数
                if step%50==0 :
                    print(i,step,loss_)
                    print("save model：",saver.save(sess,r'./LSTM/stock.model2'))
                step+=1            
with tf.variable_scope('train',reuse=tf.AUTO_REUSE):
    train_lstm()
# Out:
# Streaming output truncated to the last 5000 lines.
# 保存模型： ./LSTM/stock.model2
# 2934 9 16.526062
# 保存模型： ./LSTM/stock.model2
# 2934 10 7.2962875
# 保存模型： ./LSTM/stock.model2
# 2934 11 5.919428
# 保存模型： ./LSTM/stock.model2
# 2934 12 1.6048623
# 保存模型： ./LSTM/stock.model2
# 2934 13 1.6366102
# 保存模型： ./LSTM/stock.model2
# 2934 14 4.0836163
# 保存模型： ./LSTM/stock.model2
# 2934 15 1.8019607
# 保存模型： ./LSTM/stock.model2
# 2934 16 0.7571977
# 保存模型： ./LSTM/stock.model2
# 2934 17 2.6981487
# 保存模型： ./LSTM/stock.model2
# 2934 18 6.6119146
# 保存模型： ./LSTM/stock.model2
# 2934 19 6.7984138
# 保存模型： ./LSTM/stock.model2
# 2934 20 3.06156
# 保存模型： ./LSTM/stock.model2
# 2934 21 7.0538435
# 保存模型： ./LSTM/stock.model2
# 2934 22 5.8463907
# 保存模型： ./LSTM/stock.model2
# 2934 23 3.1630256
# 保存模型： ./LSTM/stock.model2
# 2934 24 1.1212014
# 保存模型： ./LSTM/stock.model2
# 2934 25 0.74050665
# 保存模型： ./LSTM/stock.model2
# 2934 26 1.480772
# 保存模型： ./LSTM/stock.model2
# 2934 27 4.0820036
# 保存模型： ./LSTM/stock.model2
# 2934 28 6.4782505
# 保存模型： ./LSTM/stock.model2
# 2934 29 4.3188357
# 保存模型： ./LSTM/stock.model2
# 2934 30 3.2524157
# 保存模型： ./LSTM/stock.model2
# 2934 31 5.0228767
# 保存模型： ./LSTM/stock.model2
# 2934 32 3.1412416
# 保存模型： ./LSTM/stock.model2
# 2934 33 3.2848246
# 保存模型： ./LSTM/stock.model2
# 2934 34 2.8073034
# 保存模型： ./LSTM/stock.model2
# 2934 35 3.1427824
# 保存模型： ./LSTM/stock.model2
# 2934 36 4.930496
# 保存模型： ./LSTM/stock.model2
# 2934 37 5.669119
# 保存模型： ./LSTM/stock.model2
# 2935 0 45.55732
# 保存模型： ./LSTM/stock.model2
# 2935 1 74.23801
# 保存模型： ./LSTM/stock.model2
# 2935 2 74.88023
# 保存模型： ./LSTM/stock.model2
# 2935 3 49.873993
# 保存模型： ./LSTM/stock.model2
# 2935 4 46.026016
# 保存模型： ./LSTM/stock.model2
# 2935 5 49.15344
# 保存模型： ./LSTM/stock.model2
# 2935 6 57.004265
# 保存模型： ./LSTM/stock.model2
# 2935 7 29.432875
# 保存模型： ./LSTM/stock.model2
# 2935 8 21.501947
# 保存模型： ./LSTM/stock.model2
# 2935 9 11.134821
# 保存模型： ./LSTM/stock.model2
# 2935 10 6.0212913
# 保存模型： ./LSTM/stock.model2
# 2935 11 4.8748126
# 保存模型： ./LSTM/stock.model2
# 2935 12 1.8310541
# 保存模型： ./LSTM/stock.model2
# 2935 13 1.7623523
# 保存模型： ./LSTM/stock.model2
# 2935 14 2.8895311
# 保存模型： ./LSTM/stock.model2
# 2935 15 2.232172
# 保存模型： ./LSTM/stock.model2
# 2935 16 0.89513034
# 保存模型： ./LSTM/stock.model2
# 2935 17 3.5740674
# 保存模型： ./LSTM/stock.model2
# 2935 18 4.8754716
# 保存模型： ./LSTM/stock.model2
# 2935 19 5.842273
# 保存模型： ./LSTM/stock.model2
# 2935 20 2.5414314
# 保存模型： ./LSTM/stock.model2
# 2935 21 6.8732243
# 保存模型： ./LSTM/stock.model2
# 2935 22 6.408403
# 保存模型： ./LSTM/stock.model2
# 2935 23 3.9965303
# 保存模型： ./LSTM/stock.model2
# 2935 24 2.2014258
# 保存模型： ./LSTM/stock.model2
# 2935 25 1.5159968
# 保存模型： ./LSTM/stock.model2
# 2935 26 2.0652874
# 保存模型： ./LSTM/stock.model2
# 2935 27 4.0791516
# 保存模型： ./LSTM/stock.model2
# 2935 28 4.537886
# 保存模型： ./LSTM/stock.model2
# 2935 29 3.728986
# 保存模型： ./LSTM/stock.model2
# 2935 30 3.5282214
# 保存模型： ./LSTM/stock.model2
# 2935 31 5.8264604
# 保存模型： ./LSTM/stock.model2
# 2935 32 3.3051925
# 保存模型： ./LSTM/stock.model2
# 2935 33 3.5359
# 保存模型： ./LSTM/stock.model2
# 2935 34 3.3040133
# 保存模型： ./LSTM/stock.model2
# 2935 35 3.4207954
# 保存模型： ./LSTM/stock.model2
# 2935 36 5.7975135
# 保存模型： ./LSTM/stock.model2
# 2935 37 7.0325413
# 保存模型： ./LSTM/stock.model2
# 2936 0 75.094
# 保存模型： ./LSTM/stock.model2
# 2936 1 149.62051
# 保存模型： ./LSTM/stock.model2
# 2936 2 81.41781
# 保存模型： ./LSTM/stock.model2
# 2936 3 29.049381
# 保存模型： ./LSTM/stock.model2
# 2936 4 26.423038
# 保存模型： ./LSTM/stock.model2
# 2936 5 28.343552
# 保存模型： ./LSTM/stock.model2
# 2936 6 29.670273
# 保存模型： ./LSTM/stock.model2
# 2936 7 26.814663
# 保存模型： ./LSTM/stock.model2
# 2936 8 22.181845
# 保存模型： ./LSTM/stock.model2
# 2936 9 11.021989
# 保存模型： ./LSTM/stock.model2
# 2936 10 7.152702
# 保存模型： ./LSTM/stock.model2
# 2936 11 5.5093417
# 保存模型： ./LSTM/stock.model2
# 2936 12 1.541394
# 保存模型： ./LSTM/stock.model2
# 2936 13 1.660878
# 保存模型： ./LSTM/stock.model2
# 2936 14 3.3453968
# 保存模型： ./LSTM/stock.model2
# 2936 15 1.5535825
# 保存模型： ./LSTM/stock.model2
# 2936 16 0.70948607
# 保存模型： ./LSTM/stock.model2
# 2936 17 3.0746715
# 保存模型： ./LSTM/stock.model2
# 2936 18 6.1572266
# 保存模型： ./LSTM/stock.model2
# 2936 19 7.3449464
# 保存模型： ./LSTM/stock.model2
# 2936 20 2.3309472
# 保存模型： ./LSTM/stock.model2
# 2936 21 9.029814
# 保存模型： ./LSTM/stock.model2
# 2936 22 4.812557
# 保存模型： ./LSTM/stock.model2
# 2936 23 3.2624972
# 保存模型： ./LSTM/stock.model2
# 2936 24 1.2636777
# 保存模型： ./LSTM/stock.model2
# 2936 25 0.70987123
# 保存模型： ./LSTM/stock.model2
# 2936 26 1.4280133
# 保存模型： ./LSTM/stock.model2
# 2936 27 4.1538663
# 保存模型： ./LSTM/stock.model2
# 2936 28 5.297312
# 保存模型： ./LSTM/stock.model2
# 2936 29 3.9154203
# 保存模型： ./LSTM/stock.model2
# 2936 30 3.257561
# 保存模型： ./LSTM/stock.model2
# 2936 31 5.461641
# 保存模型： ./LSTM/stock.model2
# 2936 32 3.7157044
# 保存模型： ./LSTM/stock.model2
# 2936 33 3.5944042
# 保存模型： ./LSTM/stock.model2
# 2936 34 2.6265216
# 保存模型： ./LSTM/stock.model2
# 2936 35 2.94868
# 保存模型： ./LSTM/stock.model2
# 2936 36 5.866451
# 保存模型： ./LSTM/stock.model2
# 2936 37 5.118249
# 保存模型： ./LSTM/stock.model2
# 2937 0 61.833126
# 保存模型： ./LSTM/stock.model2
# 2937 1 78.225945
# 保存模型： ./LSTM/stock.model2
# 2937 2 77.17093
# 保存模型： ./LSTM/stock.model2
# 2937 3 43.322136
# 保存模型： ./LSTM/stock.model2
# 2937 4 43.043964
# 保存模型： ./LSTM/stock.model2
# 2937 5 57.52821
# 保存模型： ./LSTM/stock.model2
# 2937 6 52.009003
# 保存模型： ./LSTM/stock.model2
# 2937 7 41.98147
# 保存模型： ./LSTM/stock.model2
# 2937 8 23.938482
# 保存模型： ./LSTM/stock.model2
# 2937 9 13.223143
# 保存模型： ./LSTM/stock.model2
# 2937 10 9.748143
# 保存模型： ./LSTM/stock.model2
# 2937 11 3.4537458
# 保存模型： ./LSTM/stock.model2
# 2937 12 1.1146104
# 保存模型： ./LSTM/stock.model2
# 2937 13 1.6266743
# 保存模型： ./LSTM/stock.model2
# 2937 14 2.641417
# 保存模型： ./LSTM/stock.model2
# 2937 15 1.9268919
# 保存模型： ./LSTM/stock.model2
# 2937 16 1.0893817
# 保存模型： ./LSTM/stock.model2
# 2937 17 2.5807114
# 保存模型： ./LSTM/stock.model2
# 2937 18 7.54153
# 保存模型： ./LSTM/stock.model2
# 2937 19 6.428741
# 保存模型： ./LSTM/stock.model2
# 2937 20 2.3376963
# 保存模型： ./LSTM/stock.model2
# 2937 21 7.0149527
# 保存模型： ./LSTM/stock.model2
# 2937 22 6.14299
# 保存模型： ./LSTM/stock.model2
# 2937 23 3.4898508
# 保存模型： ./LSTM/stock.model2
# 2937 24 1.6803545
# 保存模型： ./LSTM/stock.model2
# 2937 25 1.0389417
# 保存模型： ./LSTM/stock.model2
# 2937 26 2.09336
# 保存模型： ./LSTM/stock.model2
# 2937 27 4.1234097
# 保存模型： ./LSTM/stock.model2
# 2937 28 4.664358
# 保存模型： ./LSTM/stock.model2
# 2937 29 4.9191103
# 保存模型： ./LSTM/stock.model2
# 2937 30 3.254749
# 保存模型： ./LSTM/stock.model2
# 2937 31 4.528373
# 保存模型： ./LSTM/stock.model2
# 2937 32 3.2567797
# 保存模型： ./LSTM/stock.model2
# 2937 33 3.816139
# 保存模型： ./LSTM/stock.model2
# 2937 34 3.217061
# 保存模型： ./LSTM/stock.model2
# 2937 35 3.2638683
# 保存模型： ./LSTM/stock.model2
# 2937 36 5.547885
# 保存模型： ./LSTM/stock.model2
# 2937 37 6.387844
# 保存模型： ./LSTM/stock.model2
# 2938 0 104.57041
# 保存模型： ./LSTM/stock.model2
# 2938 1 120.56005
# 保存模型： ./LSTM/stock.model2
# 2938 2 83.89905
# 保存模型： ./LSTM/stock.model2
# 2938 3 44.994884
# 保存模型： ./LSTM/stock.model2
# 2938 4 23.532152
# 保存模型： ./LSTM/stock.model2
# 2938 5 27.327435
# 保存模型： ./LSTM/stock.model2
# 2938 6 28.965498
# 保存模型： ./LSTM/stock.model2
# 2938 7 24.18226
# 保存模型： ./LSTM/stock.model2
# 2938 8 19.375217
# 保存模型： ./LSTM/stock.model2
# 2938 9 17.127066
# 保存模型： ./LSTM/stock.model2
# 2938 10 9.699758
# 保存模型： ./LSTM/stock.model2
# 2938 11 6.105519
# 保存模型： ./LSTM/stock.model2
# 2938 12 1.4834577
# 保存模型： ./LSTM/stock.model2
# 2938 13 1.5619045
# 保存模型： ./LSTM/stock.model2
# 2938 14 3.2116714
# 保存模型： ./LSTM/stock.model2
# 2938 15 1.8842267
# 保存模型： ./LSTM/stock.model2
# 2938 16 0.88623637
# 保存模型： ./LSTM/stock.model2
# 2938 17 2.6729171
# 保存模型： ./LSTM/stock.model2
# 2938 18 6.4634027
# 保存模型： ./LSTM/stock.model2
# 2938 19 6.1018934
# 保存模型： ./LSTM/stock.model2
# 2938 20 2.8568041
# 保存模型： ./LSTM/stock.model2
# 2938 21 6.398067
# 保存模型： ./LSTM/stock.model2
# 2938 22 5.434333
# 保存模型： ./LSTM/stock.model2
# 2938 23 2.812572
# 保存模型： ./LSTM/stock.model2
# 2938 24 1.2455912
# 保存模型： ./LSTM/stock.model2
# 2938 25 0.8098233
# 保存模型： ./LSTM/stock.model2
# 2938 26 1.5601667
# 保存模型： ./LSTM/stock.model2
# 2938 27 4.245166
# 保存模型： ./LSTM/stock.model2
# 2938 28 4.932461
# 保存模型： ./LSTM/stock.model2
# 2938 29 3.6228454
# 保存模型： ./LSTM/stock.model2
# 2938 30 3.460429
# 保存模型： ./LSTM/stock.model2
# 2938 31 3.6315117
# 保存模型： ./LSTM/stock.model2
# 2938 32 3.0383875
# 保存模型： ./LSTM/stock.model2
# 2938 33 3.2347631
# 保存模型： ./LSTM/stock.model2
# 2938 34 2.7491643
# 保存模型： ./LSTM/stock.model2
# 2938 35 2.533129
# 保存模型： ./LSTM/stock.model2
# 2938 36 4.3714285
# 保存模型： ./LSTM/stock.model2
# 2938 37 4.925236
# 保存模型： ./LSTM/stock.model2
# 2939 0 53.532173
# 保存模型： ./LSTM/stock.model2
# 2939 1 87.33552
# 保存模型： ./LSTM/stock.model2
# 2939 2 76.27263
# 保存模型： ./LSTM/stock.model2
# 2939 3 47.863537
# 保存模型： ./LSTM/stock.model2
# 2939 4 45.997467
# 保存模型： ./LSTM/stock.model2
# 2939 5 36.295856
# 保存模型： ./LSTM/stock.model2
# 2939 6 54.579823
# 保存模型： ./LSTM/stock.model2
# 2939 7 25.704496
# 保存模型： ./LSTM/stock.model2
# 2939 8 18.328987
# 保存模型： ./LSTM/stock.model2
# 2939 9 15.786359
# 保存模型： ./LSTM/stock.model2
# 2939 10 7.4925895
# 保存模型： ./LSTM/stock.model2
# 2939 11 3.2116344
# 保存模型： ./LSTM/stock.model2
# 2939 12 1.4052048
# 保存模型： ./LSTM/stock.model2
# 2939 13 1.628485
# 保存模型： ./LSTM/stock.model2
# 2939 14 2.850191
# 保存模型： ./LSTM/stock.model2
# 2939 15 1.7256132
# 保存模型： ./LSTM/stock.model2
# 2939 16 1.351067
# 保存模型： ./LSTM/stock.model2
# 2939 17 2.9235914
# 保存模型： ./LSTM/stock.model2
# 2939 18 8.210755
# 保存模型： ./LSTM/stock.model2
# 2939 19 6.7548776
# 保存模型： ./LSTM/stock.model2
# 2939 20 2.0751362
# 保存模型： ./LSTM/stock.model2
# 2939 21 7.737177
# 保存模型： ./LSTM/stock.model2
# 2939 22 6.2075315
# 保存模型： ./LSTM/stock.model2
# 2939 23 3.985819
# 保存模型： ./LSTM/stock.model2
# 2939 24 1.8578238
# 保存模型： ./LSTM/stock.model2
# 2939 25 1.326846
# 保存模型： ./LSTM/stock.model2
# 2939 26 2.2245579
# 保存模型： ./LSTM/stock.model2
# 2939 27 3.906237
# 保存模型： ./LSTM/stock.model2
# 2939 28 5.027171
# 保存模型： ./LSTM/stock.model2
# 2939 29 4.078889
# 保存模型： ./LSTM/stock.model2
# 2939 30 3.0288546
# 保存模型： ./LSTM/stock.model2
# 2939 31 4.5578604
# 保存模型： ./LSTM/stock.model2
# 2939 32 3.8490343
# 保存模型： ./LSTM/stock.model2
# 2939 33 3.3007255
# 保存模型： ./LSTM/stock.model2
# 2939 34 3.0755913
# 保存模型： ./LSTM/stock.model2
# 2939 35 3.506445
# 保存模型： ./LSTM/stock.model2
# 2939 36 6.046999
# 保存模型： ./LSTM/stock.model2
# 2939 37 7.2015615
# 保存模型： ./LSTM/stock.model2
# 2940 0 76.2924
# 保存模型： ./LSTM/stock.model2
# 2940 1 137.66823
# 保存模型： ./LSTM/stock.model2
# 2940 2 65.57591
# 保存模型： ./LSTM/stock.model2
# 2940 3 36.88273
# 保存模型： ./LSTM/stock.model2
# 2940 4 34.923492
# 保存模型： ./LSTM/stock.model2
# 2940 5 28.706825
# 保存模型： ./LSTM/stock.model2
# 2940 6 35.292774
# 保存模型： ./LSTM/stock.model2
# 2940 7 32.44328
# 保存模型： ./LSTM/stock.model2
# 2940 8 17.12539
# 保存模型： ./LSTM/stock.model2
# 2940 9 14.811849
# 保存模型： ./LSTM/stock.model2
# 2940 10 7.205274
# 保存模型： ./LSTM/stock.model2
# 2940 11 4.9704723
# 保存模型： ./LSTM/stock.model2
# 2940 12 1.6127818
# 保存模型： ./LSTM/stock.model2
# 2940 13 2.0738816
# 保存模型： ./LSTM/stock.model2
# 2940 14 3.004288
# 保存模型： ./LSTM/stock.model2
# 2940 15 1.8600155
# 保存模型： ./LSTM/stock.model2
# 2940 16 0.6717554
# 保存模型： ./LSTM/stock.model2
# 2940 17 3.3124578
# 保存模型： ./LSTM/stock.model2
# 2940 18 6.128104
# 保存模型： ./LSTM/stock.model2
# 2940 19 6.414135
# 保存模型： ./LSTM/stock.model2
# 2940 20 2.446674
# 保存模型： ./LSTM/stock.model2
# 2940 21 6.6452394
# 保存模型： ./LSTM/stock.model2
# 2940 22 6.231317
# 保存模型： ./LSTM/stock.model2
# 2940 23 3.2938282
# 保存模型： ./LSTM/stock.model2
# 2940 24 1.3435515
# 保存模型： ./LSTM/stock.model2
# 2940 25 0.6938915
# 保存模型： ./LSTM/stock.model2
# 2940 26 1.5661678
# 保存模型： ./LSTM/stock.model2
# 2940 27 3.7673755
# 保存模型： ./LSTM/stock.model2
# 2940 28 5.164267
# 保存模型： ./LSTM/stock.model2
# 2940 29 3.985538
# 保存模型： ./LSTM/stock.model2
# 2940 30 4.464891
# 保存模型： ./LSTM/stock.model2
# 2940 31 4.6269717
# 保存模型： ./LSTM/stock.model2
# 2940 32 3.2248354
# 保存模型： ./LSTM/stock.model2
# 2940 33 3.1675167
# 保存模型： ./LSTM/stock.model2
# 2940 34 2.839574
# 保存模型： ./LSTM/stock.model2
# 2940 35 2.624685
# 保存模型： ./LSTM/stock.model2
# 2940 36 4.572146
# 保存模型： ./LSTM/stock.model2
# 2940 37 5.111217
# 保存模型： ./LSTM/stock.model2
# 2941 0 73.144615
# 保存模型： ./LSTM/stock.model2
# 2941 1 82.02793
# 保存模型： ./LSTM/stock.model2
# 2941 2 102.91422
# 保存模型： ./LSTM/stock.model2
# 2941 3 73.88206
# 保存模型： ./LSTM/stock.model2
# 2941 4 44.043465
# 保存模型： ./LSTM/stock.model2
# 2941 5 50.438416
# 保存模型： ./LSTM/stock.model2
# 2941 6 51.53515
# 保存模型： ./LSTM/stock.model2
# 2941 7 40.16094
# 保存模型： ./LSTM/stock.model2
# 2941 8 19.09163
# 保存模型： ./LSTM/stock.model2
# 2941 9 10.043432
# 保存模型： ./LSTM/stock.model2
# 2941 10 5.9712224
# 保存模型： ./LSTM/stock.model2
# 2941 11 3.6079826
# 保存模型： ./LSTM/stock.model2
# 2941 12 1.1263992
# 保存模型： ./LSTM/stock.model2
# 2941 13 1.8394458
# 保存模型： ./LSTM/stock.model2
# 2941 14 2.6095011
# 保存模型： ./LSTM/stock.model2
# 2941 15 2.3508663
# 保存模型： ./LSTM/stock.model2
# 2941 16 1.1713133
# 保存模型： ./LSTM/stock.model2
# 2941 17 3.9370525
# 保存模型： ./LSTM/stock.model2
# 2941 18 7.731026
# 保存模型： ./LSTM/stock.model2
# 2941 19 6.6662235
# 保存模型： ./LSTM/stock.model2
# 2941 20 1.3977027
# 保存模型： ./LSTM/stock.model2
# 2941 21 7.500244
# 保存模型： ./LSTM/stock.model2
# 2941 22 7.2278476
# 保存模型： ./LSTM/stock.model2
# 2941 23 4.1582603
# 保存模型： ./LSTM/stock.model2
# 2941 24 1.9719089
# 保存模型： ./LSTM/stock.model2
# 2941 25 1.4407485
# 保存模型： ./LSTM/stock.model2
# 2941 26 2.4442856
# 保存模型： ./LSTM/stock.model2
# 2941 27 4.3472867
# 保存模型： ./LSTM/stock.model2
# 2941 28 5.916884
# 保存模型： ./LSTM/stock.model2
# 2941 29 4.220043
# 保存模型： ./LSTM/stock.model2
# 2941 30 3.890439
# 保存模型： ./LSTM/stock.model2
# 2941 31 4.539115
# 保存模型： ./LSTM/stock.model2
# 2941 32 3.3720045
# 保存模型： ./LSTM/stock.model2
# 2941 33 3.463927
# 保存模型： ./LSTM/stock.model2
# 2941 34 3.7284358
# 保存模型： ./LSTM/stock.model2
# 2941 35 3.2369766
# 保存模型： ./LSTM/stock.model2
# 2941 36 6.004597
# 保存模型： ./LSTM/stock.model2
# 2941 37 6.407806
# 保存模型： ./LSTM/stock.model2
# 2942 0 100.39475
# 保存模型： ./LSTM/stock.model2
# 2942 1 133.46767
# 保存模型： ./LSTM/stock.model2
# 2942 2 93.86551
# 保存模型： ./LSTM/stock.model2
# 2942 3 38.794872
# 保存模型： ./LSTM/stock.model2
# 2942 4 26.642853
# 保存模型： ./LSTM/stock.model2
# 2942 5 36.086838
# 保存模型： ./LSTM/stock.model2
# 2942 6 26.542921
# 保存模型： ./LSTM/stock.model2
# 2942 7 26.581526
# 保存模型： ./LSTM/stock.model2
# 2942 8 21.239822
# 保存模型： ./LSTM/stock.model2
# 2942 9 13.381772
# 保存模型： ./LSTM/stock.model2
# 2942 10 7.2851887
# 保存模型： ./LSTM/stock.model2
# 2942 11 5.6178336
# 保存模型： ./LSTM/stock.model2
# 2942 12 1.6384426
# 保存模型： ./LSTM/stock.model2
# 2942 13 1.770617
# 保存模型： ./LSTM/stock.model2
# 2942 14 3.395279
# 保存模型： ./LSTM/stock.model2
# 2942 15 1.6871635
# 保存模型： ./LSTM/stock.model2
# 2942 16 0.6497383
# 保存模型： ./LSTM/stock.model2
# 2942 17 2.628922
# 保存模型： ./LSTM/stock.model2
# 2942 18 6.7856655
# 保存模型： ./LSTM/stock.model2
# 2942 19 6.9031234
# 保存模型： ./LSTM/stock.model2
# 2942 20 3.317219
# 保存模型： ./LSTM/stock.model2
# 2942 21 7.699669
# 保存模型： ./LSTM/stock.model2
# 2942 22 6.3825903
# 保存模型： ./LSTM/stock.model2
# 2942 23 3.3623173
# 保存模型： ./LSTM/stock.model2
# 2942 24 1.3094283
# 保存模型： ./LSTM/stock.model2
# 2942 25 0.68035907
# 保存模型： ./LSTM/stock.model2
# 2942 26 1.4188375
# 保存模型： ./LSTM/stock.model2
# 2942 27 3.9215882
# 保存模型： ./LSTM/stock.model2
# 2942 28 6.7462673
# 保存模型： ./LSTM/stock.model2
# 2942 29 4.5200386
# 保存模型： ./LSTM/stock.model2
# 2942 30 3.6574137
# 保存模型： ./LSTM/stock.model2
# 2942 31 4.9332848
# 保存模型： ./LSTM/stock.model2
# 2942 32 3.0644789
# 保存模型： ./LSTM/stock.model2
# 2942 33 3.0084202
# 保存模型： ./LSTM/stock.model2
# 2942 34 3.2547643
# 保存模型： ./LSTM/stock.model2
# 2942 35 2.8561933
# 保存模型： ./LSTM/stock.model2
# 2942 36 4.963057
# 保存模型： ./LSTM/stock.model2
# 2942 37 5.081811
# 保存模型： ./LSTM/stock.model2
# 2943 0 71.30019
# 保存模型： ./LSTM/stock.model2
# 2943 1 73.58547
# 保存模型： ./LSTM/stock.model2
# 2943 2 79.44996
# 保存模型： ./LSTM/stock.model2
# 2943 3 60.474075
# 保存模型： ./LSTM/stock.model2
# 2943 4 58.33405
# 保存模型： ./LSTM/stock.model2
# 2943 5 49.757202
# 保存模型： ./LSTM/stock.model2
# 2943 6 49.313965
# 保存模型： ./LSTM/stock.model2
# 2943 7 29.799124
# 保存模型： ./LSTM/stock.model2
# 2943 8 29.804163
# 保存模型： ./LSTM/stock.model2
# 2943 9 9.998449
# 保存模型： ./LSTM/stock.model2
# 2943 10 6.411145
# 保存模型： ./LSTM/stock.model2
# 2943 11 3.62105
# 保存模型： ./LSTM/stock.model2
# 2943 12 1.284298
# 保存模型： ./LSTM/stock.model2
# 2943 13 2.029121
# 保存模型： ./LSTM/stock.model2
# 2943 14 2.7406778
# 保存模型： ./LSTM/stock.model2
# 2943 15 1.8916557
# 保存模型： ./LSTM/stock.model2
# 2943 16 0.75404334
# 保存模型： ./LSTM/stock.model2
# 2943 17 3.566561
# 保存模型： ./LSTM/stock.model2
# 2943 18 8.386201
# 保存模型： ./LSTM/stock.model2
# 2943 19 4.9869494
# 保存模型： ./LSTM/stock.model2
# 2943 20 2.1092224
# 保存模型： ./LSTM/stock.model2
# 2943 21 8.749535
# 保存模型： ./LSTM/stock.model2
# 2943 22 6.0660563
# 保存模型： ./LSTM/stock.model2
# 2943 23 3.9770036
# 保存模型： ./LSTM/stock.model2
# 2943 24 1.990105
# 保存模型： ./LSTM/stock.model2
# 2943 25 1.4570663
# 保存模型： ./LSTM/stock.model2
# 2943 26 2.332308
# 保存模型： ./LSTM/stock.model2
# 2943 27 4.1522655
# 保存模型： ./LSTM/stock.model2
# 2943 28 4.0331926
# 保存模型： ./LSTM/stock.model2
# 2943 29 3.848333
# 保存模型： ./LSTM/stock.model2
# 2943 30 3.337521
# 保存模型： ./LSTM/stock.model2
# 2943 31 5.3756685
# 保存模型： ./LSTM/stock.model2
# 2943 32 3.0123668
# 保存模型： ./LSTM/stock.model2
# 2943 33 4.022632
# 保存模型： ./LSTM/stock.model2
# 2943 34 2.4663227
# 保存模型： ./LSTM/stock.model2
# 2943 35 3.5050004
# 保存模型： ./LSTM/stock.model2
# 2943 36 5.2481256
# 保存模型： ./LSTM/stock.model2
# 2943 37 7.6338906
# 保存模型： ./LSTM/stock.model2
# 2944 0 89.088455
# 保存模型： ./LSTM/stock.model2
# 2944 1 139.93607
# 保存模型： ./LSTM/stock.model2
# 2944 2 64.48945
# 保存模型： ./LSTM/stock.model2
# 2944 3 26.055632
# 保存模型： ./LSTM/stock.model2
# 2944 4 24.546782
# 保存模型： ./LSTM/stock.model2
# 2944 5 36.20668
# 保存模型： ./LSTM/stock.model2
# 2944 6 34.201523
# 保存模型： ./LSTM/stock.model2
# 2944 7 22.630522
# 保存模型： ./LSTM/stock.model2
# 2944 8 20.374126
# 保存模型： ./LSTM/stock.model2
# 2944 9 9.891288
# 保存模型： ./LSTM/stock.model2
# 2944 10 5.1685815
# 保存模型： ./LSTM/stock.model2
# 2944 11 5.8875847
# 保存模型： ./LSTM/stock.model2
# 2944 12 1.6164421
# 保存模型： ./LSTM/stock.model2
# 2944 13 1.9543699
# 保存模型： ./LSTM/stock.model2
# 2944 14 3.304609
# 保存模型： ./LSTM/stock.model2
# 2944 15 2.0360103
# 保存模型： ./LSTM/stock.model2
# 2944 16 0.97749674
# 保存模型： ./LSTM/stock.model2
# 2944 17 2.5166652
# 保存模型： ./LSTM/stock.model2
# 2944 18 6.832553
# 保存模型： ./LSTM/stock.model2
# 2944 19 7.7231445
# 保存模型： ./LSTM/stock.model2
# 2944 20 2.0792997
# 保存模型： ./LSTM/stock.model2
# 2944 21 7.4508514
# 保存模型： ./LSTM/stock.model2
# 2944 22 3.8128357
# 保存模型： ./LSTM/stock.model2
# 2944 23 3.309555
# 保存模型： ./LSTM/stock.model2
# 2944 24 1.2655604
# 保存模型： ./LSTM/stock.model2
# 2944 25 0.9911426
# 保存模型： ./LSTM/stock.model2
# 2944 26 1.3039484
# 保存模型： ./LSTM/stock.model2
# 2944 27 2.773533
# 保存模型： ./LSTM/stock.model2
# 2944 28 4.717884
# 保存模型： ./LSTM/stock.model2
# 2944 29 3.9232264
# 保存模型： ./LSTM/stock.model2
# 2944 30 4.020332
# 保存模型： ./LSTM/stock.model2
# 2944 31 4.5678086
# 保存模型： ./LSTM/stock.model2
# 2944 32 3.0906222
# 保存模型： ./LSTM/stock.model2
# 2944 33 3.1677504
# 保存模型： ./LSTM/stock.model2
# 2944 34 2.6321466
# 保存模型： ./LSTM/stock.model2
# 2944 35 2.937548
# 保存模型： ./LSTM/stock.model2
# 2944 36 5.2657437
# 保存模型： ./LSTM/stock.model2
# 2944 37 5.837013
# 保存模型： ./LSTM/stock.model2
# 2945 0 69.75873
# 保存模型： ./LSTM/stock.model2
# 2945 1 72.931274
# 保存模型： ./LSTM/stock.model2
# 2945 2 79.38066
# 保存模型： ./LSTM/stock.model2
# 2945 3 62.274517
# 保存模型： ./LSTM/stock.model2
# 2945 4 52.474777
# 保存模型： ./LSTM/stock.model2
# 2945 5 43.770393
# 保存模型： ./LSTM/stock.model2
# 2945 6 50.930035
# 保存模型： ./LSTM/stock.model2
# 2945 7 30.99459
# 保存模型： ./LSTM/stock.model2
# 2945 8 22.956064
# 保存模型： ./LSTM/stock.model2
# 2945 9 11.759894
# 保存模型： ./LSTM/stock.model2
# 2945 10 7.670501
# 保存模型： ./LSTM/stock.model2
# 2945 11 3.456932
# 保存模型： ./LSTM/stock.model2
# 2945 12 1.0549132
# 保存模型： ./LSTM/stock.model2
# 2945 13 1.5707009
# 保存模型： ./LSTM/stock.model2
# 2945 14 2.903124
# 保存模型： ./LSTM/stock.model2
# 2945 15 1.9703729
# 保存模型： ./LSTM/stock.model2
# 2945 16 1.0344979
# 保存模型： ./LSTM/stock.model2
# 2945 17 3.60579
# 保存模型： ./LSTM/stock.model2
# 2945 18 6.430922
# 保存模型： ./LSTM/stock.model2
# 2945 19 8.005088
# 保存模型： ./LSTM/stock.model2
# 2945 20 2.0841832
# 保存模型： ./LSTM/stock.model2
# 2945 21 5.663374
# 保存模型： ./LSTM/stock.model2
# 2945 22 4.4006524
# 保存模型： ./LSTM/stock.model2
# 2945 23 3.9415405
# 保存模型： ./LSTM/stock.model2
# 2945 24 1.8640828
# 保存模型： ./LSTM/stock.model2
# 2945 25 1.3660449
# 保存模型： ./LSTM/stock.model2
# 2945 26 2.362942
# 保存模型： ./LSTM/stock.model2
# 2945 27 4.2021575
# 保存模型： ./LSTM/stock.model2
# 2945 28 5.68583
# 保存模型： ./LSTM/stock.model2
# 2945 29 4.4194264
# 保存模型： ./LSTM/stock.model2
# 2945 30 4.0022993
# 保存模型： ./LSTM/stock.model2
# 2945 31 4.5428677
# 保存模型： ./LSTM/stock.model2
# 2945 32 3.6889787
# 保存模型： ./LSTM/stock.model2
# 2945 33 3.000399
# 保存模型： ./LSTM/stock.model2
# 2945 34 3.189218
# 保存模型： ./LSTM/stock.model2
# 2945 35 3.5410583
# 保存模型： ./LSTM/stock.model2
# 2945 36 6.6547556
# 保存模型： ./LSTM/stock.model2
# 2945 37 6.8641233
# 保存模型： ./LSTM/stock.model2
# 2946 0 83.548615
# 保存模型： ./LSTM/stock.model2
# 2946 1 114.82346
# 保存模型： ./LSTM/stock.model2
# 2946 2 71.325645
# 保存模型： ./LSTM/stock.model2
# 2946 3 42.860596
# 保存模型： ./LSTM/stock.model2
# 2946 4 19.0138
# 保存模型： ./LSTM/stock.model2
# 2946 5 30.192644
# 保存模型： ./LSTM/stock.model2
# 2946 6 27.455599
# 保存模型： ./LSTM/stock.model2
# 2946 7 26.182976
# 保存模型： ./LSTM/stock.model2
# 2946 8 25.995466
# 保存模型： ./LSTM/stock.model2
# 2946 9 11.298742
# 保存模型： ./LSTM/stock.model2
# 2946 10 7.032876
# 保存模型： ./LSTM/stock.model2
# 2946 11 6.6785545
# 保存模型： ./LSTM/stock.model2
# 2946 12 1.0806272
# 保存模型： ./LSTM/stock.model2
# 2946 13 1.802205
# 保存模型： ./LSTM/stock.model2
# 2946 14 3.3486843
# 保存模型： ./LSTM/stock.model2
# 2946 15 1.6813744
# 保存模型： ./LSTM/stock.model2
# 2946 16 1.1929096
# 保存模型： ./LSTM/stock.model2
# 2946 17 3.155798
# 保存模型： ./LSTM/stock.model2
# 2946 18 9.046683
# 保存模型： ./LSTM/stock.model2
# 2946 19 7.4691153
# 保存模型： ./LSTM/stock.model2
# 2946 20 3.0710998
# 保存模型： ./LSTM/stock.model2
# 2946 21 8.26846
# 保存模型： ./LSTM/stock.model2
# 2946 22 7.3726764
# 保存模型： ./LSTM/stock.model2
# 2946 23 3.2026439
# 保存模型： ./LSTM/stock.model2
# 2946 24 1.1720413
# 保存模型： ./LSTM/stock.model2
# 2946 25 0.6940833
# 保存模型： ./LSTM/stock.model2
# 2946 26 1.714716
# 保存模型： ./LSTM/stock.model2
# 2946 27 3.8029773
# 保存模型： ./LSTM/stock.model2
# 2946 28 5.98472
# 保存模型： ./LSTM/stock.model2
# 2946 29 4.1433563
# 保存模型： ./LSTM/stock.model2
# 2946 30 4.415266
# 保存模型： ./LSTM/stock.model2
# 2946 31 4.8823566
# 保存模型： ./LSTM/stock.model2
# 2946 32 3.2951694
# 保存模型： ./LSTM/stock.model2
# 2946 33 3.1599076
# 保存模型： ./LSTM/stock.model2
# 2946 34 3.2612057
# 保存模型： ./LSTM/stock.model2
# 2946 35 3.026097
# 保存模型： ./LSTM/stock.model2
# 2946 36 5.3064823
# 保存模型： ./LSTM/stock.model2
# 2946 37 5.062843
# 保存模型： ./LSTM/stock.model2
# 2947 0 61.348404
# 保存模型： ./LSTM/stock.model2
# 2947 1 71.77941
# 保存模型： ./LSTM/stock.model2
# 2947 2 92.97431
# 保存模型： ./LSTM/stock.model2
# 2947 3 79.67304
# 保存模型： ./LSTM/stock.model2
# 2947 4 57.73023
# 保存模型： ./LSTM/stock.model2
# 2947 5 53.992798
# 保存模型： ./LSTM/stock.model2
# 2947 6 46.283257
# 保存模型： ./LSTM/stock.model2
# 2947 7 30.70082
# 保存模型： ./LSTM/stock.model2
# 2947 8 26.67511
# 保存模型： ./LSTM/stock.model2
# 2947 9 16.284042
# 保存模型： ./LSTM/stock.model2
# 2947 10 6.3507886
# 保存模型： ./LSTM/stock.model2
# 2947 11 4.717755
# 保存模型： ./LSTM/stock.model2
# 2947 12 1.4910457
# 保存模型： ./LSTM/stock.model2
# 2947 13 1.879419
# 保存模型： ./LSTM/stock.model2
# 2947 14 2.3419995
# 保存模型： ./LSTM/stock.model2
# 2947 15 1.9220976
# 保存模型： ./LSTM/stock.model2
# 2947 16 1.163609
# 保存模型： ./LSTM/stock.model2
# 2947 17 3.1577325
# 保存模型： ./LSTM/stock.model2
# 2947 18 7.1352944
# 保存模型： ./LSTM/stock.model2
# 2947 19 8.360679
# 保存模型： ./LSTM/stock.model2
# 2947 20 1.9903162
# 保存模型： ./LSTM/stock.model2
# 2947 21 7.017646
# 保存模型： ./LSTM/stock.model2
# 2947 22 6.155646
# 保存模型： ./LSTM/stock.model2
# 2947 23 4.8771954
# 保存模型： ./LSTM/stock.model2
# 2947 24 1.9807495
# 保存模型： ./LSTM/stock.model2
# 2947 25 1.6082711
# 保存模型： ./LSTM/stock.model2
# 2947 26 2.1677103
# 保存模型： ./LSTM/stock.model2
# 2947 27 4.1839323
# 保存模型： ./LSTM/stock.model2
# 2947 28 7.145652
# 保存模型： ./LSTM/stock.model2
# 2947 29 3.3520217
# 保存模型： ./LSTM/stock.model2
# 2947 30 3.6553524
# 保存模型： ./LSTM/stock.model2
# 2947 31 5.643988
# 保存模型： ./LSTM/stock.model2
# 2947 32 3.5054927
# 保存模型： ./LSTM/stock.model2
# 2947 33 4.1954117
# 保存模型： ./LSTM/stock.model2
# 2947 34 3.4218318
# 保存模型： ./LSTM/stock.model2
# 2947 35 3.6832557
# 保存模型： ./LSTM/stock.model2
# 2947 36 6.025667
# 保存模型： ./LSTM/stock.model2
# 2947 37 7.083247
# 保存模型： ./LSTM/stock.model2
# 2948 0 83.31689
# 保存模型： ./LSTM/stock.model2
# 2948 1 149.01256
# 保存模型： ./LSTM/stock.model2
# 2948 2 84.87408
# 保存模型： ./LSTM/stock.model2
# 2948 3 43.120293
# 保存模型： ./LSTM/stock.model2
# 2948 4 19.868765
# 保存模型： ./LSTM/stock.model2
# 2948 5 30.687471
# 保存模型： ./LSTM/stock.model2
# 2948 6 40.82466
# 保存模型： ./LSTM/stock.model2
# 2948 7 31.691038
# 保存模型： ./LSTM/stock.model2
# 2948 8 15.601242
# 保存模型： ./LSTM/stock.model2
# 2948 9 19.267418
# 保存模型： ./LSTM/stock.model2
# 2948 10 5.2626076
# 保存模型： ./LSTM/stock.model2
# 2948 11 5.451233
# 保存模型： ./LSTM/stock.model2
# 2948 12 1.8273273
# 保存模型： ./LSTM/stock.model2
# 2948 13 1.9648649
# 保存模型： ./LSTM/stock.model2
# 2948 14 3.1622047
# 保存模型： ./LSTM/stock.model2
# 2948 15 1.7379018
# 保存模型： ./LSTM/stock.model2
# 2948 16 0.6628707
# 保存模型： ./LSTM/stock.model2
# 2948 17 2.3854606
# 保存模型： ./LSTM/stock.model2
# 2948 18 6.6863556
# 保存模型： ./LSTM/stock.model2
# 2948 19 6.397014
# 保存模型： ./LSTM/stock.model2
# 2948 20 2.9001355
# 保存模型： ./LSTM/stock.model2
# 2948 21 6.5484467
# 保存模型： ./LSTM/stock.model2
# 2948 22 5.814839
# 保存模型： ./LSTM/stock.model2
# 2948 23 3.0463028
# 保存模型： ./LSTM/stock.model2
# 2948 24 1.4255666
# 保存模型： ./LSTM/stock.model2
# 2948 25 0.70123553
# 保存模型： ./LSTM/stock.model2
# 2948 26 1.6595355
# 保存模型： ./LSTM/stock.model2
# 2948 27 3.3885896
# 保存模型： ./LSTM/stock.model2
# 2948 28 4.5968356
# 保存模型： ./LSTM/stock.model2
# 2948 29 3.6335206
# 保存模型： ./LSTM/stock.model2
# 2948 30 4.082385
# 保存模型： ./LSTM/stock.model2
# 2948 31 4.995277
# 保存模型： ./LSTM/stock.model2
# 2948 32 3.0371253
# 保存模型： ./LSTM/stock.model2
# 2948 33 3.6847098
# 保存模型： ./LSTM/stock.model2
# 2948 34 3.197156
# 保存模型： ./LSTM/stock.model2
# 2948 35 3.0836978
# 保存模型： ./LSTM/stock.model2
# 2948 36 5.0699615
# 保存模型： ./LSTM/stock.model2
# 2948 37 5.633109
# 保存模型： ./LSTM/stock.model2
# 2949 0 63.27293
# 保存模型： ./LSTM/stock.model2
# 2949 1 53.871822
# 保存模型： ./LSTM/stock.model2
# 2949 2 72.61894
# 保存模型： ./LSTM/stock.model2
# 2949 3 47.211926
# 保存模型： ./LSTM/stock.model2
# 2949 4 36.644314
# 保存模型： ./LSTM/stock.model2
# 2949 5 44.28401
# 保存模型： ./LSTM/stock.model2
# 2949 6 41.406483
# 保存模型： ./LSTM/stock.model2
# 2949 7 25.096727
# 保存模型： ./LSTM/stock.model2
# 2949 8 27.053247
# 保存模型： ./LSTM/stock.model2
# 2949 9 9.388605
# 保存模型： ./LSTM/stock.model2
# 2949 10 7.68119
# 保存模型： ./LSTM/stock.model2
# 2949 11 3.8116386
# 保存模型： ./LSTM/stock.model2
# 2949 12 1.1897782
# 保存模型： ./LSTM/stock.model2
# 2949 13 1.433424
# 保存模型： ./LSTM/stock.model2
# 2949 14 2.7568433
# 保存模型： ./LSTM/stock.model2
# 2949 15 2.448338
# 保存模型： ./LSTM/stock.model2
# 2949 16 1.1770343
# 保存模型： ./LSTM/stock.model2
# 2949 17 2.8490434
# 保存模型： ./LSTM/stock.model2
# 2949 18 6.8154345
# 保存模型： ./LSTM/stock.model2
# 2949 19 6.0949926
# 保存模型： ./LSTM/stock.model2
# 2949 20 2.2334635
# 保存模型： ./LSTM/stock.model2
# 2949 21 6.409968
# 保存模型： ./LSTM/stock.model2
# 2949 22 7.8007812
# 保存模型： ./LSTM/stock.model2
# 2949 23 3.6917045
# 保存模型： ./LSTM/stock.model2
# 2949 24 1.7245593
# 保存模型： ./LSTM/stock.model2
# 2949 25 1.2265257
# 保存模型： ./LSTM/stock.model2
# 2949 26 2.1924176
# 保存模型： ./LSTM/stock.model2
# 2949 27 4.316256
# 保存模型： ./LSTM/stock.model2
# 2949 28 6.629454
# 保存模型： ./LSTM/stock.model2
# 2949 29 3.189253
# 保存模型： ./LSTM/stock.model2
# 2949 30 3.5122497
# 保存模型： ./LSTM/stock.model2
# 2949 31 4.1711755
# 保存模型： ./LSTM/stock.model2
# 2949 32 2.8246722
# 保存模型： ./LSTM/stock.model2
# 2949 33 3.7215812
# 保存模型： ./LSTM/stock.model2
# 2949 34 3.6767797
# 保存模型： ./LSTM/stock.model2
# 2949 35 3.437583
# 保存模型： ./LSTM/stock.model2
# 2949 36 5.37542
# 保存模型： ./LSTM/stock.model2
# 2949 37 6.7792506
# 保存模型： ./LSTM/stock.model2
# 2950 0 82.94098
# 保存模型： ./LSTM/stock.model2
# 2950 1 105.71636
# 保存模型： ./LSTM/stock.model2
# 2950 2 80.82155
# 保存模型： ./LSTM/stock.model2
# 2950 3 41.225254
# 保存模型： ./LSTM/stock.model2
# 2950 4 23.333477
# 保存模型： ./LSTM/stock.model2
# 2950 5 41.491577
# 保存模型： ./LSTM/stock.model2
# 2950 6 24.288427
# 保存模型： ./LSTM/stock.model2
# 2950 7 29.605745
# 保存模型： ./LSTM/stock.model2
# 2950 8 15.612995
# 保存模型： ./LSTM/stock.model2
# 2950 9 9.741554
# 保存模型： ./LSTM/stock.model2
# 2950 10 7.133638
# 保存模型： ./LSTM/stock.model2
# 2950 11 6.5015316
# 保存模型： ./LSTM/stock.model2
# 2950 12 1.6585085
# 保存模型： ./LSTM/stock.model2
# 2950 13 1.6831667
# 保存模型： ./LSTM/stock.model2
# 2950 14 3.5198233
# 保存模型： ./LSTM/stock.model2
# 2950 15 1.6568382
# 保存模型： ./LSTM/stock.model2
# 2950 16 0.9230664
# 保存模型： ./LSTM/stock.model2
# 2950 17 2.5764666
# 保存模型： ./LSTM/stock.model2
# 2950 18 6.4448867
# 保存模型： ./LSTM/stock.model2
# 2950 19 7.0150423
# 保存模型： ./LSTM/stock.model2
# 2950 20 2.5751212
# 保存模型： ./LSTM/stock.model2
# 2950 21 5.574952
# 保存模型： ./LSTM/stock.model2
# 2950 22 7.81799
# 保存模型： ./LSTM/stock.model2
# 2950 23 3.1837869
# 保存模型： ./LSTM/stock.model2
# 2950 24 1.2456157
# 保存模型： ./LSTM/stock.model2
# 2950 25 0.68940616
# 保存模型： ./LSTM/stock.model2
# 2950 26 1.4780111
# 保存模型： ./LSTM/stock.model2
# 2950 27 3.8769279
# 保存模型： ./LSTM/stock.model2
# 2950 28 5.800602
# 保存模型： ./LSTM/stock.model2
# 2950 29 3.0608985
# 保存模型： ./LSTM/stock.model2
# 2950 30 3.62736
# 保存模型： ./LSTM/stock.model2
# 2950 31 4.9297523
# 保存模型： ./LSTM/stock.model2
# 2950 32 2.6037312
# 保存模型： ./LSTM/stock.model2
# 2950 33 3.0076594
# 保存模型： ./LSTM/stock.model2
# 2950 34 2.8864338
# 保存模型： ./LSTM/stock.model2
# 2950 35 2.597392
# 保存模型： ./LSTM/stock.model2
# 2950 36 5.827373
# 保存模型： ./LSTM/stock.model2
# 2950 37 5.0290813
# 保存模型： ./LSTM/stock.model2
# 2951 0 65.792305
# 保存模型： ./LSTM/stock.model2
# 2951 1 80.48819
# 保存模型： ./LSTM/stock.model2
# 2951 2 69.39142
# 保存模型： ./LSTM/stock.model2
# 2951 3 47.487442
# 保存模型： ./LSTM/stock.model2
# 2951 4 45.17992
# 保存模型： ./LSTM/stock.model2
# 2951 5 50.02788
# 保存模型： ./LSTM/stock.model2
# 2951 6 32.581627
# 保存模型： ./LSTM/stock.model2
# 2951 7 26.450922
# 保存模型： ./LSTM/stock.model2
# 2951 8 15.050553
# 保存模型： ./LSTM/stock.model2
# 2951 9 13.692712
# 保存模型： ./LSTM/stock.model2
# 2951 10 7.32562
# 保存模型： ./LSTM/stock.model2
# 2951 11 3.5561657
# 保存模型： ./LSTM/stock.model2
# 2951 12 1.2632917
# 保存模型： ./LSTM/stock.model2
# 2951 13 1.4904312
# 保存模型： ./LSTM/stock.model2
# 2951 14 2.4675932
# 保存模型： ./LSTM/stock.model2
# 2951 15 1.7707548
# 保存模型： ./LSTM/stock.model2
# 2951 16 0.99136597
# 保存模型： ./LSTM/stock.model2
# 2951 17 2.9077835
# 保存模型： ./LSTM/stock.model2
# 2951 18 6.8819695
# 保存模型： ./LSTM/stock.model2
# 2951 19 7.24924
# 保存模型： ./LSTM/stock.model2
# 2951 20 2.2522647
# 保存模型： ./LSTM/stock.model2
# 2951 21 7.2607512
# 保存模型： ./LSTM/stock.model2
# 2951 22 6.9667015
# 保存模型： ./LSTM/stock.model2
# 2951 23 3.559458
# 保存模型： ./LSTM/stock.model2
# 2951 24 1.5400076
# 保存模型： ./LSTM/stock.model2
# 2951 25 1.1965841
# 保存模型： ./LSTM/stock.model2
# 2951 26 2.0098798
# 保存模型： ./LSTM/stock.model2
# 2951 27 3.3128688
# 保存模型： ./LSTM/stock.model2
# 2951 28 5.3840756
# 保存模型： ./LSTM/stock.model2
# 2951 29 3.2777307
# 保存模型： ./LSTM/stock.model2
# 2951 30 3.576785
# 保存模型： ./LSTM/stock.model2
# 2951 31 5.209627
# 保存模型： ./LSTM/stock.model2
# 2951 32 3.509024
# 保存模型： ./LSTM/stock.model2
# 2951 33 3.4866729
# 保存模型： ./LSTM/stock.model2
# 2951 34 3.3692973
# 保存模型： ./LSTM/stock.model2
# 2951 35 3.0411105
# 保存模型： ./LSTM/stock.model2
# 2951 36 5.482104
# 保存模型： ./LSTM/stock.model2
# 2951 37 6.888579
# 保存模型： ./LSTM/stock.model2
# 2952 0 82.80605
# 保存模型： ./LSTM/stock.model2
# 2952 1 112.051796
# 保存模型： ./LSTM/stock.model2
# 2952 2 63.038242
# 保存模型： ./LSTM/stock.model2
# 2952 3 26.556496
# 保存模型： ./LSTM/stock.model2
# 2952 4 16.977459
# 保存模型： ./LSTM/stock.model2
# 2952 5 37.21831
# 保存模型： ./LSTM/stock.model2
# 2952 6 28.5586
# 保存模型： ./LSTM/stock.model2
# 2952 7 21.699923
# 保存模型： ./LSTM/stock.model2
# 2952 8 19.781366
# 保存模型： ./LSTM/stock.model2
# 2952 9 15.489315
# 保存模型： ./LSTM/stock.model2
# 2952 10 4.9002113
# 保存模型： ./LSTM/stock.model2
# 2952 11 6.7074933
# 保存模型： ./LSTM/stock.model2
# 2952 12 1.3455516
# 保存模型： ./LSTM/stock.model2
# 2952 13 1.6063604
# 保存模型： ./LSTM/stock.model2
# 2952 14 3.7309155
# 保存模型： ./LSTM/stock.model2
# 2952 15 1.5028778
# 保存模型： ./LSTM/stock.model2
# 2952 16 1.1992763
# 保存模型： ./LSTM/stock.model2
# 2952 17 2.8112874
# 保存模型： ./LSTM/stock.model2
# 2952 18 4.961425
# 保存模型： ./LSTM/stock.model2
# 2952 19 6.398064
# 保存模型： ./LSTM/stock.model2
# 2952 20 2.3596156
# 保存模型： ./LSTM/stock.model2
# 2952 21 7.428718
# 保存模型： ./LSTM/stock.model2
# 2952 22 4.49579
# 保存模型： ./LSTM/stock.model2
# 2952 23 3.6327262
# 保存模型： ./LSTM/stock.model2
# 2952 24 1.2123883
# 保存模型： ./LSTM/stock.model2
# 2952 25 0.6282143
# 保存模型： ./LSTM/stock.model2
# 2952 26 1.6157628
# 保存模型： ./LSTM/stock.model2
# 2952 27 3.8914692
# 保存模型： ./LSTM/stock.model2
# 2952 28 4.9846706
# 保存模型： ./LSTM/stock.model2
# 2952 29 3.6369197
# 保存模型： ./LSTM/stock.model2
# 2952 30 4.262038
# 保存模型： ./LSTM/stock.model2
# 2952 31 4.3271837
# 保存模型： ./LSTM/stock.model2
# 2952 32 3.533477
# 保存模型： ./LSTM/stock.model2
# 2952 33 3.2590852
# 保存模型： ./LSTM/stock.model2
# 2952 34 2.115601
# 保存模型： ./LSTM/stock.model2
# 2952 35 2.7545943
# 保存模型： ./LSTM/stock.model2
# 2952 36 5.3846846
# 保存模型： ./LSTM/stock.model2
# 2952 37 5.2814927
# 保存模型： ./LSTM/stock.model2
# 2953 0 74.56096
# 保存模型： ./LSTM/stock.model2
# 2953 1 95.79817
# 保存模型： ./LSTM/stock.model2
# 2953 2 93.35821
# 保存模型： ./LSTM/stock.model2
# 2953 3 41.728703
# 保存模型： ./LSTM/stock.model2
# 2953 4 40.47203
# 保存模型： ./LSTM/stock.model2
# 2953 5 38.370743
# 保存模型： ./LSTM/stock.model2
# 2953 6 34.81413
# 保存模型： ./LSTM/stock.model2
# 2953 7 23.951715
# 保存模型： ./LSTM/stock.model2
# 2953 8 17.530132
# 保存模型： ./LSTM/stock.model2
# 2953 9 11.607767
# 保存模型： ./LSTM/stock.model2
# 2953 10 7.059866
# 保存模型： ./LSTM/stock.model2
# 2953 11 3.4908915
# 保存模型： ./LSTM/stock.model2
# 2953 12 1.1461686
# 保存模型： ./LSTM/stock.model2
# 2953 13 1.796839
# 保存模型： ./LSTM/stock.model2
# 2953 14 2.926481
# 保存模型： ./LSTM/stock.model2
# 2953 15 1.9315064
# 保存模型： ./LSTM/stock.model2
# 2953 16 0.82524395
# 保存模型： ./LSTM/stock.model2
# 2953 17 2.917747
# 保存模型： ./LSTM/stock.model2
# 2953 18 4.9520473
# 保存模型： ./LSTM/stock.model2
# 2953 19 9.50275
# 保存模型： ./LSTM/stock.model2
# 2953 20 2.3075893
# 保存模型： ./LSTM/stock.model2
# 2953 21 6.570119
# 保存模型： ./LSTM/stock.model2
# 2953 22 6.3797355
# 保存模型： ./LSTM/stock.model2
# 2953 23 3.2791638
# 保存模型： ./LSTM/stock.model2
# 2953 24 1.4297061
# 保存模型： ./LSTM/stock.model2
# 2953 25 1.149307
# 保存模型： ./LSTM/stock.model2
# 2953 26 1.9346824
# 保存模型： ./LSTM/stock.model2
# 2953 27 3.8798528
# 保存模型： ./LSTM/stock.model2
# 2953 28 4.900623
# 保存模型： ./LSTM/stock.model2
# 2953 29 4.375494
# 保存模型： ./LSTM/stock.model2
# 2953 30 3.063346
# 保存模型： ./LSTM/stock.model2
# 2953 31 4.2868357
# 保存模型： ./LSTM/stock.model2
# 2953 32 4.010964
# 保存模型： ./LSTM/stock.model2
# 2953 33 4.1516514
# 保存模型： ./LSTM/stock.model2
# 2953 34 2.885884
# 保存模型： ./LSTM/stock.model2
# 2953 35 3.5275798
# 保存模型： ./LSTM/stock.model2
# 2953 36 5.111826
# 保存模型： ./LSTM/stock.model2
# 2953 37 6.579999
# 保存模型： ./LSTM/stock.model2
# 2954 0 82.90163
# 保存模型： ./LSTM/stock.model2
# 2954 1 92.13359
# 保存模型： ./LSTM/stock.model2
# 2954 2 80.7005
# 保存模型： ./LSTM/stock.model2
# 2954 3 21.855669
# 保存模型： ./LSTM/stock.model2
# 2954 4 24.342953
# 保存模型： ./LSTM/stock.model2
# 2954 5 26.34483
# 保存模型： ./LSTM/stock.model2
# 2954 6 34.45704
# 保存模型： ./LSTM/stock.model2
# 2954 7 23.6659
# 保存模型： ./LSTM/stock.model2
# 2954 8 18.082718
# 保存模型： ./LSTM/stock.model2
# 2954 9 17.729479
# 保存模型： ./LSTM/stock.model2
# 2954 10 9.490524
# 保存模型： ./LSTM/stock.model2
# 2954 11 5.925049
# 保存模型： ./LSTM/stock.model2
# 2954 12 1.6362828
# 保存模型： ./LSTM/stock.model2
# 2954 13 1.8212193
# 保存模型： ./LSTM/stock.model2
# 2954 14 2.9310448
# 保存模型： ./LSTM/stock.model2
# 2954 15 1.9258752
# 保存模型： ./LSTM/stock.model2
# 2954 16 0.75294834
# 保存模型： ./LSTM/stock.model2
# 2954 17 2.9168568
# 保存模型： ./LSTM/stock.model2
# 2954 18 6.294258
# 保存模型： ./LSTM/stock.model2
# 2954 19 5.796882
# 保存模型： ./LSTM/stock.model2
# 2954 20 2.6635852
# 保存模型： ./LSTM/stock.model2
# 2954 21 7.6145515
# 保存模型： ./LSTM/stock.model2
# 2954 22 5.203963
# 保存模型： ./LSTM/stock.model2
# 2954 23 3.296725
# 保存模型： ./LSTM/stock.model2
# 2954 24 1.2541358
# 保存模型： ./LSTM/stock.model2
# 2954 25 0.7484947
# 保存模型： ./LSTM/stock.model2
# 2954 26 1.3412123
# 保存模型： ./LSTM/stock.model2
# 2954 27 4.585782
# 保存模型： ./LSTM/stock.model2
# 2954 28 5.643555
# 保存模型： ./LSTM/stock.model2
# 2954 29 3.719275
# 保存模型： ./LSTM/stock.model2
# 2954 30 3.790244
# 保存模型： ./LSTM/stock.model2
# 2954 31 4.1223083
# 保存模型： ./LSTM/stock.model2
# 2954 32 2.5512989
# 保存模型： ./LSTM/stock.model2
# 2954 33 3.095844
# 保存模型： ./LSTM/stock.model2
# 2954 34 3.5453775
# 保存模型： ./LSTM/stock.model2
# 2954 35 2.7723396
# 保存模型： ./LSTM/stock.model2
# 2954 36 5.014872
# 保存模型： ./LSTM/stock.model2
# 2954 37 5.484282
# 保存模型： ./LSTM/stock.model2
# 2955 0 70.40164
# 保存模型： ./LSTM/stock.model2
# 2955 1 111.14807
# 保存模型： ./LSTM/stock.model2
# 2955 2 76.543076
# 保存模型： ./LSTM/stock.model2
# 2955 3 56.40249
# 保存模型： ./LSTM/stock.model2
# 2955 4 34.636196
# 保存模型： ./LSTM/stock.model2
# 2955 5 27.75229
# 保存模型： ./LSTM/stock.model2
# 2955 6 45.328335
# 保存模型： ./LSTM/stock.model2
# 2955 7 28.305527
# 保存模型： ./LSTM/stock.model2
# 2955 8 20.765026
# 保存模型： ./LSTM/stock.model2
# 2955 9 8.716841
# 保存模型： ./LSTM/stock.model2
# 2955 10 8.031071
# 保存模型： ./LSTM/stock.model2
# 2955 11 3.1244771
# 保存模型： ./LSTM/stock.model2
# 2955 12 1.2208807
# 保存模型： ./LSTM/stock.model2
# 2955 13 1.9253896
# 保存模型： ./LSTM/stock.model2
# 2955 14 2.4672759
# 保存模型： ./LSTM/stock.model2
# 2955 15 1.8948289
# 保存模型： ./LSTM/stock.model2
# 2955 16 0.8455553
# 保存模型： ./LSTM/stock.model2
# 2955 17 2.4139328
# 保存模型： ./LSTM/stock.model2
# 2955 18 6.1220713
# 保存模型： ./LSTM/stock.model2
# 2955 19 6.2855597
# 保存模型： ./LSTM/stock.model2
# 2955 20 1.903067
# 保存模型： ./LSTM/stock.model2
# 2955 21 4.622853
# 保存模型： ./LSTM/stock.model2
# 2955 22 5.90613
# 保存模型： ./LSTM/stock.model2
# 2955 23 3.6210597
# 保存模型： ./LSTM/stock.model2
# 2955 24 1.6651664
# 保存模型： ./LSTM/stock.model2
# 2955 25 1.2870386
# 保存模型： ./LSTM/stock.model2
# 2955 26 1.8335537
# 保存模型： ./LSTM/stock.model2
# 2955 27 3.5503047
# 保存模型： ./LSTM/stock.model2
# 2955 28 4.889859
# 保存模型： ./LSTM/stock.model2
# 2955 29 4.283917
# 保存模型： ./LSTM/stock.model2
# 2955 30 3.1371684
# 保存模型： ./LSTM/stock.model2
# 2955 31 3.2741609
# 保存模型： ./LSTM/stock.model2
# 2955 32 2.8748312
# 保存模型： ./LSTM/stock.model2
# 2955 33 3.5275578
# 保存模型： ./LSTM/stock.model2
# 2955 34 3.6513221
# 保存模型： ./LSTM/stock.model2
# 2955 35 3.4636064
# 保存模型： ./LSTM/stock.model2
# 2955 36 5.922078
# 保存模型： ./LSTM/stock.model2
# 2955 37 7.4301977
# 保存模型： ./LSTM/stock.model2
# 2956 0 100.45019
# 保存模型： ./LSTM/stock.model2
# 2956 1 105.61896
# 保存模型： ./LSTM/stock.model2
# 2956 2 67.80773
# 保存模型： ./LSTM/stock.model2
# 2956 3 41.049355
# 保存模型： ./LSTM/stock.model2
# 2956 4 22.346022
# 保存模型： ./LSTM/stock.model2
# 2956 5 43.301796
# 保存模型： ./LSTM/stock.model2
# 2956 6 41.936142
# 保存模型： ./LSTM/stock.model2
# 2956 7 30.587952
# 保存模型： ./LSTM/stock.model2
# 2956 8 21.24131
# 保存模型： ./LSTM/stock.model2
# 2956 9 11.89208
# 保存模型： ./LSTM/stock.model2
# 2956 10 8.477393
# 保存模型： ./LSTM/stock.model2
# 2956 11 5.0305166
# 保存模型： ./LSTM/stock.model2
# 2956 12 1.622469
# 保存模型： ./LSTM/stock.model2
# 2956 13 1.5470085
# 保存模型： ./LSTM/stock.model2
# 2956 14 3.3369703
# 保存模型： ./LSTM/stock.model2
# 2956 15 1.881629
# 保存模型： ./LSTM/stock.model2
# 2956 16 0.69588065
# 保存模型： ./LSTM/stock.model2
# 2956 17 2.4708369
# 保存模型： ./LSTM/stock.model2
# 2956 18 6.725048
# 保存模型： ./LSTM/stock.model2
# 2956 19 6.5388765
# 保存模型： ./LSTM/stock.model2
# 2956 20 3.3660896
# 保存模型： ./LSTM/stock.model2
# 2956 21 7.7390723
# 保存模型： ./LSTM/stock.model2
# 2956 22 4.38056
# 保存模型： ./LSTM/stock.model2
# 2956 23 3.2608147
# 保存模型： ./LSTM/stock.model2
# 2956 24 1.1230295
# 保存模型： ./LSTM/stock.model2
# 2956 25 0.7604379
# 保存模型： ./LSTM/stock.model2
# 2956 26 1.4052346
# 保存模型： ./LSTM/stock.model2
# 2956 27 3.581988
# 保存模型： ./LSTM/stock.model2
# 2956 28 5.926126
# 保存模型： ./LSTM/stock.model2
# 2956 29 3.9919152
# 保存模型： ./LSTM/stock.model2
# 2956 30 3.879906
# 保存模型： ./LSTM/stock.model2
# 2956 31 4.608835
# 保存模型： ./LSTM/stock.model2
# 2956 32 3.9434514
# 保存模型： ./LSTM/stock.model2
# 2956 33 2.703612
# 保存模型： ./LSTM/stock.model2
# 2956 34 2.4239337
# 保存模型： ./LSTM/stock.model2
# 2956 35 3.1544824
# 保存模型： ./LSTM/stock.model2
# 2956 36 5.3070784
# 保存模型： ./LSTM/stock.model2
# 2956 37 5.406647
# 保存模型： ./LSTM/stock.model2
# 2957 0 68.4723
# 保存模型： ./LSTM/stock.model2
# 2957 1 76.686424
# 保存模型： ./LSTM/stock.model2
# 2957 2 90.839584
# 保存模型： ./LSTM/stock.model2
# 2957 3 57.0934
# 保存模型： ./LSTM/stock.model2
# 2957 4 46.518612
# 保存模型： ./LSTM/stock.model2
# 2957 5 40.34323
# 保存模型： ./LSTM/stock.model2
# 2957 6 34.566406
# 保存模型： ./LSTM/stock.model2
# 2957 7 30.914883
# 保存模型： ./LSTM/stock.model2
# 2957 8 19.054323
# 保存模型： ./LSTM/stock.model2
# 2957 9 12.636587
# 保存模型： ./LSTM/stock.model2
# 2957 10 7.4901886
# 保存模型： ./LSTM/stock.model2
# 2957 11 3.1795962
# 保存模型： ./LSTM/stock.model2
# 2957 12 1.305865
# 保存模型： ./LSTM/stock.model2
# 2957 13 1.8721904
# 保存模型： ./LSTM/stock.model2
# 2957 14 2.4695835
# 保存模型： ./LSTM/stock.model2
# 2957 15 1.991855
# 保存模型： ./LSTM/stock.model2
# 2957 16 1.2989262
# 保存模型： ./LSTM/stock.model2
# 2957 17 3.8698156
# 保存模型： ./LSTM/stock.model2
# 2957 18 8.225594
# 保存模型： ./LSTM/stock.model2
# 2957 19 5.6875725
# 保存模型： ./LSTM/stock.model2
# 2957 20 2.5390582
# 保存模型： ./LSTM/stock.model2
# 2957 21 8.965461
# 保存模型： ./LSTM/stock.model2
# 2957 22 5.963841
# 保存模型： ./LSTM/stock.model2
# 2957 23 3.4540234
# 保存模型： ./LSTM/stock.model2
# 2957 24 1.7149189
# 保存模型： ./LSTM/stock.model2
# 2957 25 1.2103337
# 保存模型： ./LSTM/stock.model2
# 2957 26 1.9890629
# 保存模型： ./LSTM/stock.model2
# 2957 27 3.7688482
# 保存模型： ./LSTM/stock.model2
# 2957 28 5.119733
# 保存模型： ./LSTM/stock.model2
# 2957 29 4.261861
# 保存模型： ./LSTM/stock.model2
# 2957 30 4.1401453
# 保存模型： ./LSTM/stock.model2
# 2957 31 5.3022695
# 保存模型： ./LSTM/stock.model2
# 2957 32 3.3577986
# 保存模型： ./LSTM/stock.model2
# 2957 33 4.1763716
# 保存模型： ./LSTM/stock.model2
# 2957 34 2.902754
# 保存模型： ./LSTM/stock.model2
# 2957 35 3.199158
# 保存模型： ./LSTM/stock.model2
# 2957 36 5.401424
# 保存模型： ./LSTM/stock.model2
# 2957 37 6.2323356
# 保存模型： ./LSTM/stock.model2
# 2958 0 85.192535
# 保存模型： ./LSTM/stock.model2
# 2958 1 128.28099
# 保存模型： ./LSTM/stock.model2
# 2958 2 67.65523
# 保存模型： ./LSTM/stock.model2
# 2958 3 31.72518
# 保存模型： ./LSTM/stock.model2
# 2958 4 18.801754
# 保存模型： ./LSTM/stock.model2
# 2958 5 30.185911
# 保存模型： ./LSTM/stock.model2
# 2958 6 25.117895
# 保存模型： ./LSTM/stock.model2
# 2958 7 23.374117
# 保存模型： ./LSTM/stock.model2
# 2958 8 21.378828
# 保存模型： ./LSTM/stock.model2
# 2958 9 11.4383745
# 保存模型： ./LSTM/stock.model2
# 2958 10 7.240231
# 保存模型： ./LSTM/stock.model2
# 2958 11 6.1646824
# 保存模型： ./LSTM/stock.model2
# 2958 12 1.4932932
# 保存模型： ./LSTM/stock.model2
# 2958 13 1.5463064
# 保存模型： ./LSTM/stock.model2
# 2958 14 3.663186
# 保存模型： ./LSTM/stock.model2
# 2958 15 1.8684572
# 保存模型： ./LSTM/stock.model2
# 2958 16 1.041745
# 保存模型： ./LSTM/stock.model2
# 2958 17 3.0873194
# 保存模型： ./LSTM/stock.model2
# 2958 18 10.230156
# 保存模型： ./LSTM/stock.model2
# 2958 19 5.5391817
# 保存模型： ./LSTM/stock.model2
# 2958 20 3.3317688
# 保存模型： ./LSTM/stock.model2
# 2958 21 8.537409
# 保存模型： ./LSTM/stock.model2
# 2958 22 4.9885936
# 保存模型： ./LSTM/stock.model2
# 2958 23 3.4315796
# 保存模型： ./LSTM/stock.model2
# 2958 24 1.0291626
# 保存模型： ./LSTM/stock.model2
# 2958 25 0.7225102
# 保存模型： ./LSTM/stock.model2
# 2958 26 1.4153428
# 保存模型： ./LSTM/stock.model2
# 2958 27 3.6591032
# 保存模型： ./LSTM/stock.model2
# 2958 28 5.395001
# 保存模型： ./LSTM/stock.model2
# 2958 29 4.3171954
# 保存模型： ./LSTM/stock.model2
# 2958 30 3.633477
# 保存模型： ./LSTM/stock.model2
# 2958 31 5.454423
# 保存模型： ./LSTM/stock.model2
# 2958 32 4.08701
# 保存模型： ./LSTM/stock.model2
# 2958 33 3.2807152
# 保存模型： ./LSTM/stock.model2
# 2958 34 2.742533
# 保存模型： ./LSTM/stock.model2
# 2958 35 3.3539667
# 保存模型： ./LSTM/stock.model2
# 2958 36 4.8064117
# 保存模型： ./LSTM/stock.model2
# 2958 37 5.1807404
# 保存模型： ./LSTM/stock.model2
# 2959 0 108.38616
# 保存模型： ./LSTM/stock.model2
# 2959 1 83.545525
# 保存模型： ./LSTM/stock.model2
# 2959 2 66.80529
# 保存模型： ./LSTM/stock.model2
# 2959 3 64.720856
# 保存模型： ./LSTM/stock.model2
# 2959 4 34.176704
# 保存模型： ./LSTM/stock.model2
# 2959 5 40.30074
# 保存模型： ./LSTM/stock.model2
# 2959 6 38.373177
# 保存模型： ./LSTM/stock.model2
# 2959 7 23.133768
# 保存模型： ./LSTM/stock.model2
# 2959 8 28.343468
# 保存模型： ./LSTM/stock.model2
# 2959 9 14.36976
# 保存模型： ./LSTM/stock.model2
# 2959 10 6.786683
# 保存模型： ./LSTM/stock.model2
# 2959 11 5.6856813
# 保存模型： ./LSTM/stock.model2
# 2959 12 1.592909
# 保存模型： ./LSTM/stock.model2
# 2959 13 1.421678
# 保存模型： ./LSTM/stock.model2
# 2959 14 2.8557732
# 保存模型： ./LSTM/stock.model2
# 2959 15 1.7274271
# 保存模型： ./LSTM/stock.model2
# 2959 16 1.0648509
# 保存模型： ./LSTM/stock.model2
# 2959 17 2.4095232
# 保存模型： ./LSTM/stock.model2
# 2959 18 7.75962
# 保存模型： ./LSTM/stock.model2
# 2959 19 5.7229104
# 保存模型： ./LSTM/stock.model2
# 2959 20 1.5781198
# 保存模型： ./LSTM/stock.model2
# 2959 21 8.590772
# 保存模型： ./LSTM/stock.model2
# 2959 22 4.901007
# 保存模型： ./LSTM/stock.model2
# 2959 23 3.5517013
# 保存模型： ./LSTM/stock.model2
# 2959 24 1.6731731
# 保存模型： ./LSTM/stock.model2
# 2959 25 0.9678004
# 保存模型： ./LSTM/stock.model2
# 2959 26 1.6889564
# 保存模型： ./LSTM/stock.model2
# 2959 27 3.7288883
# 保存模型： ./LSTM/stock.model2
# 2959 28 5.631627
# 保存模型： ./LSTM/stock.model2
# 2959 29 3.3322926
# 保存模型： ./LSTM/stock.model2
# 2959 30 4.3235707
# 保存模型： ./LSTM/stock.model2
# 2959 31 6.387927
# 保存模型： ./LSTM/stock.model2
# 2959 32 3.6384408
# 保存模型： ./LSTM/stock.model2
# 2959 33 3.6638925
# 保存模型： ./LSTM/stock.model2
# 2959 34 3.165856
# 保存模型： ./LSTM/stock.model2
# 2959 35 3.110029
# 保存模型： ./LSTM/stock.model2
# 2959 36 5.1866026
# 保存模型： ./LSTM/stock.model2
# 2959 37 7.4390635
# 保存模型： ./LSTM/stock.model2
# 2960 0 104.098305
# 保存模型： ./LSTM/stock.model2
# 2960 1 109.89521
# 保存模型： ./LSTM/stock.model2
# 2960 2 80.73335
# 保存模型： ./LSTM/stock.model2
# 2960 3 36.104347
# 保存模型： ./LSTM/stock.model2
# 2960 4 25.30659
# 保存模型： ./LSTM/stock.model2
# 2960 5 40.53762
# 保存模型： ./LSTM/stock.model2
# 2960 6 32.984325
# 保存模型： ./LSTM/stock.model2
# 2960 7 23.226397
# 保存模型： ./LSTM/stock.model2
# 2960 8 20.681835
# 保存模型： ./LSTM/stock.model2
# 2960 9 13.951978
# 保存模型： ./LSTM/stock.model2
# 2960 10 6.276385
# 保存模型： ./LSTM/stock.model2
# 2960 11 5.4299045
# 保存模型： ./LSTM/stock.model2
# 2960 12 1.6600761
# 保存模型： ./LSTM/stock.model2
# 2960 13 1.5385734
# 保存模型： ./LSTM/stock.model2
# 2960 14 2.7947013
# 保存模型： ./LSTM/stock.model2
# 2960 15 1.7555859
# 保存模型： ./LSTM/stock.model2
# 2960 16 0.69317263
# 保存模型： ./LSTM/stock.model2
# 2960 17 2.8210533
# 保存模型： ./LSTM/stock.model2
# 2960 18 8.927674
# 保存模型： ./LSTM/stock.model2
# 2960 19 7.2514105
# 保存模型： ./LSTM/stock.model2
# 2960 20 2.1027234
# 保存模型： ./LSTM/stock.model2
# 2960 21 6.6513305
# 保存模型： ./LSTM/stock.model2
# 2960 22 3.9079947
# 保存模型： ./LSTM/stock.model2
# 2960 23 3.4357946
# 保存模型： ./LSTM/stock.model2
# 2960 24 1.0827696
# 保存模型： ./LSTM/stock.model2
# 2960 25 0.68863285
# 保存模型： ./LSTM/stock.model2
# 2960 26 1.6188867
# 保存模型： ./LSTM/stock.model2
# 2960 27 3.326056
# 保存模型： ./LSTM/stock.model2
# 2960 28 5.660567
# 保存模型： ./LSTM/stock.model2
# 2960 29 4.2064486
# 保存模型： ./LSTM/stock.model2
# 2960 30 2.9944382
# 保存模型： ./LSTM/stock.model2
# 2960 31 4.400969
# 保存模型： ./LSTM/stock.model2
# 2960 32 3.4130285
# 保存模型： ./LSTM/stock.model2
# 2960 33 3.8359818
# 保存模型： ./LSTM/stock.model2
# 2960 34 2.589268
# 保存模型： ./LSTM/stock.model2
# 2960 35 2.8447645
# 保存模型： ./LSTM/stock.model2
# 2960 36 4.1541734
# 保存模型： ./LSTM/stock.model2
# 2960 37 5.0651517
# 保存模型： ./LSTM/stock.model2
# 2961 0 72.46375
# 保存模型： ./LSTM/stock.model2
# 2961 1 96.92407
# 保存模型： ./LSTM/stock.model2
# 2961 2 99.988945
# 保存模型： ./LSTM/stock.model2
# 2961 3 64.98941
# 保存模型： ./LSTM/stock.model2
# 2961 4 54.710762
# 保存模型： ./LSTM/stock.model2
# 2961 5 44.279087
# 保存模型： ./LSTM/stock.model2
# 2961 6 51.791294
# 保存模型： ./LSTM/stock.model2
# 2961 7 43.2733
# 保存模型： ./LSTM/stock.model2
# 2961 8 17.598604
# 保存模型： ./LSTM/stock.model2
# 2961 9 12.60563
# 保存模型： ./LSTM/stock.model2
# 2961 10 7.4099326
# 保存模型： ./LSTM/stock.model2
# 2961 11 4.2473226
# 保存模型： ./LSTM/stock.model2
# 2961 12 0.9030125
# 保存模型： ./LSTM/stock.model2
# 2961 13 1.4997764
# 保存模型： ./LSTM/stock.model2
# 2961 14 2.9659333
# 保存模型： ./LSTM/stock.model2
# 2961 15 2.2050195
# 保存模型： ./LSTM/stock.model2
# 2961 16 1.1352687
# 保存模型： ./LSTM/stock.model2
# 2961 17 3.3946667
# 保存模型： ./LSTM/stock.model2
# 2961 18 7.311758
# 保存模型： ./LSTM/stock.model2
# 2961 19 6.256665
# 保存模型： ./LSTM/stock.model2
# 2961 20 2.2006068
# 保存模型： ./LSTM/stock.model2
# 2961 21 12.027374
# 保存模型： ./LSTM/stock.model2
# 2961 22 7.63108
# 保存模型： ./LSTM/stock.model2
# 2961 23 3.5277648
# 保存模型： ./LSTM/stock.model2
# 2961 24 1.992525
# 保存模型： ./LSTM/stock.model2
# 2961 25 1.5294129
# 保存模型： ./LSTM/stock.model2
# 2961 26 2.0783727
# 保存模型： ./LSTM/stock.model2
# 2961 27 4.673323
# 保存模型： ./LSTM/stock.model2
# 2961 28 4.533075
# 保存模型： ./LSTM/stock.model2
# 2961 29 3.793248
# 保存模型： ./LSTM/stock.model2
# 2961 30 4.526779
# 保存模型： ./LSTM/stock.model2
# 2961 31 5.1068916
# 保存模型： ./LSTM/stock.model2
# 2961 32 2.9936922
# 保存模型： ./LSTM/stock.model2
# 2961 33 3.7708762
# 保存模型： ./LSTM/stock.model2
# 2961 34 3.5605392
# 保存模型： ./LSTM/stock.model2
# 2961 35 3.5096912
# 保存模型： ./LSTM/stock.model2
# 2961 36 5.0668364
# 保存模型： ./LSTM/stock.model2
# 2961 37 7.0577784
# 保存模型： ./LSTM/stock.model2
# 2962 0 136.64833
# 保存模型： ./LSTM/stock.model2
# 2962 1 132.51053
# 保存模型： ./LSTM/stock.model2
# 2962 2 94.80811
# 保存模型： ./LSTM/stock.model2
# 2962 3 34.948425
# 保存模型： ./LSTM/stock.model2
# 2962 4 41.30974
# 保存模型： ./LSTM/stock.model2
# 2962 5 25.282152
# 保存模型： ./LSTM/stock.model2
# 2962 6 31.748066
# 保存模型： ./LSTM/stock.model2
# 2962 7 22.83566
# 保存模型： ./LSTM/stock.model2
# 2962 8 19.72596
# 保存模型： ./LSTM/stock.model2
# 2962 9 16.06527
# 保存模型： ./LSTM/stock.model2
# 2962 10 8.178809
# 保存模型： ./LSTM/stock.model2
# 2962 11 5.352332
# 保存模型： ./LSTM/stock.model2
# 2962 12 1.3808413
# 保存模型： ./LSTM/stock.model2
# 2962 13 1.3831165
# 保存模型： ./LSTM/stock.model2
# 2962 14 3.63761
# 保存模型： ./LSTM/stock.model2
# 2962 15 1.7990621
# 保存模型： ./LSTM/stock.model2
# 2962 16 0.9692858
# 保存模型： ./LSTM/stock.model2
# 2962 17 3.225373
# 保存模型： ./LSTM/stock.model2
# 2962 18 7.670075
# 保存模型： ./LSTM/stock.model2
# 2962 19 6.399154
# 保存模型： ./LSTM/stock.model2
# 2962 20 2.9751039
# 保存模型： ./LSTM/stock.model2
# 2962 21 9.331149
# 保存模型： ./LSTM/stock.model2
# 2962 22 6.6750555
# 保存模型： ./LSTM/stock.model2
# 2962 23 3.2820163
# 保存模型： ./LSTM/stock.model2
# 2962 24 1.1900897
# 保存模型： ./LSTM/stock.model2
# 2962 25 0.6954984
# 保存模型： ./LSTM/stock.model2
# 2962 26 1.1574386
# 保存模型： ./LSTM/stock.model2
# 2962 27 3.6182756
# 保存模型： ./LSTM/stock.model2
# 2962 28 5.328505
# 保存模型： ./LSTM/stock.model2
# 2962 29 3.3558815
# 保存模型： ./LSTM/stock.model2
# 2962 30 4.456415
# 保存模型： ./LSTM/stock.model2
# 2962 31 4.6033134
# 保存模型： ./LSTM/stock.model2
# 2962 32 2.9831526
# 保存模型： ./LSTM/stock.model2
# 2962 33 2.9716666
# 保存模型： ./LSTM/stock.model2
# 2962 34 2.729605
# 保存模型： ./LSTM/stock.model2
# 2962 35 2.525907
# 保存模型： ./LSTM/stock.model2
# 2962 36 4.568306
# 保存模型： ./LSTM/stock.model2
# 2962 37 4.8452377
# 保存模型： ./LSTM/stock.model2
# 2963 0 51.288273
# 保存模型： ./LSTM/stock.model2
# 2963 1 68.59229
# 保存模型： ./LSTM/stock.model2
# 2963 2 124.13151
# 保存模型： ./LSTM/stock.model2
# 2963 3 76.59785
# 保存模型： ./LSTM/stock.model2
# 2963 4 53.01451
# 保存模型： ./LSTM/stock.model2
# 2963 5 48.016136
# 保存模型： ./LSTM/stock.model2
# 2963 6 42.592785
# 保存模型： ./LSTM/stock.model2
# 2963 7 30.26241
# 保存模型： ./LSTM/stock.model2
# 2963 8 25.451376
# 保存模型： ./LSTM/stock.model2
# 2963 9 17.624098
# 保存模型： ./LSTM/stock.model2
# 2963 10 7.48195
# 保存模型： ./LSTM/stock.model2
# 2963 11 4.2781467
# ...
# 2990 12 1.6670423
# 保存模型： ./LSTM/stock.model2
# 2990 13 1.6238778
# 保存模型： ./LSTM/stock.model2
# 2990 14 3.2561603
# 保存模型： ./LSTM/stock.model2
# 2990 15 1.8197781
# 保存模型： ./LSTM/stock.model2
# 2990 16 1.1124034
# 保存模型： ./LSTM/stock.model2
# 2990 17 2.7505457
# 保存模型： ./LSTM/stock.model2
# 2990 18 5.9115143
# 保存模型： ./LSTM/stock.model2
# 2990 19 7.8905973
# 保存模型： ./LSTM/stock.model2
# 2990 20 2.5252142
# 保存模型： ./LSTM/stock.model2
# 2990 21 6.076827
# 保存模型： ./LSTM/stock.model2
# 2990 22 5.2404966
# 保存模型： ./LSTM/stock.model2
# 2990 23 3.1537123
# 保存模型： ./LSTM/stock.model2
# 2990 24 1.1714008
# 保存模型： ./LSTM/stock.model2
# 2990 25 0.6698429
# 保存模型： ./LSTM/stock.model2
# 2990 26 1.5386435
# 保存模型： ./LSTM/stock.model2
# 2990 27 4.6132
# 保存模型： ./LSTM/stock.model2
# 2990 28 6.534158
# 保存模型： ./LSTM/stock.model2
# 2990 29 3.1059508
# 保存模型： ./LSTM/stock.model2
# 2990 30 3.6899304
# 保存模型： ./LSTM/stock.model2
# 2990 31 5.969639
# 保存模型： ./LSTM/stock.model2
# 2990 32 2.5864694
# 保存模型： ./LSTM/stock.model2
# 2990 33 3.3433764
# 保存模型： ./LSTM/stock.model2
# 2990 34 3.167445
# 保存模型： ./LSTM/stock.model2
# 2990 35 2.9587343
# 保存模型： ./LSTM/stock.model2
# 2990 36 5.5455585
# 保存模型： ./LSTM/stock.model2
# 2990 37 5.15226
# 保存模型： ./LSTM/stock.model2
# 2991 0 76.48862
# 保存模型： ./LSTM/stock.model2
# 2991 1 74.15771
# 保存模型： ./LSTM/stock.model2
# 2991 2 90.966965
# 保存模型： ./LSTM/stock.model2
# 2991 3 60.123417
# 保存模型： ./LSTM/stock.model2
# 2991 4 56.33953
# 保存模型： ./LSTM/stock.model2
# 2991 5 48.869503
# 保存模型： ./LSTM/stock.model2
# 2991 6 42.002064
# 保存模型： ./LSTM/stock.model2
# 2991 7 25.058475
# 保存模型： ./LSTM/stock.model2
# 2991 8 24.018229
# 保存模型： ./LSTM/stock.model2
# 2991 9 10.19612
# 保存模型： ./LSTM/stock.model2
# 2991 10 8.453076
# 保存模型： ./LSTM/stock.model2
# 2991 11 3.891845
# 保存模型： ./LSTM/stock.model2
# 2991 12 1.4503467
# 保存模型： ./LSTM/stock.model2
# 2991 13 1.7869424
# 保存模型： ./LSTM/stock.model2
# 2991 14 2.9333754
# 保存模型： ./LSTM/stock.model2
# 2991 15 1.9307743
# 保存模型： ./LSTM/stock.model2
# 2991 16 1.2329688
# 保存模型： ./LSTM/stock.model2
# 2991 17 3.0704746
# 保存模型： ./LSTM/stock.model2
# 2991 18 6.4857483
# 保存模型： ./LSTM/stock.model2
# 2991 19 9.0153055
# 保存模型： ./LSTM/stock.model2
# 2991 20 2.1112165
# 保存模型： ./LSTM/stock.model2
# 2991 21 5.1058507
# 保存模型： ./LSTM/stock.model2
# 2991 22 8.69711
# 保存模型： ./LSTM/stock.model2
# 2991 23 3.9183304
# 保存模型： ./LSTM/stock.model2
# 2991 24 1.9703956
# 保存模型： ./LSTM/stock.model2
# 2991 25 1.3401921
# 保存模型： ./LSTM/stock.model2
# 2991 26 2.337948
# 保存模型： ./LSTM/stock.model2
# 2991 27 4.1188703
# 保存模型： ./LSTM/stock.model2
# 2991 28 4.5827208
# 保存模型： ./LSTM/stock.model2
# 2991 29 4.197503
# 保存模型： ./LSTM/stock.model2
# 2991 30 3.575099
# 保存模型： ./LSTM/stock.model2
# 2991 31 4.6597176
# 保存模型： ./LSTM/stock.model2
# 2991 32 2.9088607
# 保存模型： ./LSTM/stock.model2
# 2991 33 3.6261833
# 保存模型： ./LSTM/stock.model2
# 2991 34 3.4687898
# 保存模型： ./LSTM/stock.model2
# 2991 35 3.5888505
# 保存模型： ./LSTM/stock.model2
# 2991 36 6.112478
# 保存模型： ./LSTM/stock.model2
# 2991 37 6.5846233
# 保存模型： ./LSTM/stock.model2
# 2992 0 85.53803
# 保存模型： ./LSTM/stock.model2
# 2992 1 137.48672
# 保存模型： ./LSTM/stock.model2
# 2992 2 75.10396
# 保存模型： ./LSTM/stock.model2
# 2992 3 35.746082
# 保存模型： ./LSTM/stock.model2
# 2992 4 31.475176
# 保存模型： ./LSTM/stock.model2
# 2992 5 41.38926
# 保存模型： ./LSTM/stock.model2
# 2992 6 29.356693
# 保存模型： ./LSTM/stock.model2
# 2992 7 23.8986
# 保存模型： ./LSTM/stock.model2
# 2992 8 22.861216
# 保存模型： ./LSTM/stock.model2
# 2992 9 11.598416
# 保存模型： ./LSTM/stock.model2
# 2992 10 6.219773
# 保存模型： ./LSTM/stock.model2
# 2992 11 5.6740575
# 保存模型： ./LSTM/stock.model2
# 2992 12 1.8788548
# 保存模型： ./LSTM/stock.model2
# 2992 13 1.870936
# 保存模型： ./LSTM/stock.model2
# 2992 14 3.0517306
# 保存模型： ./LSTM/stock.model2
# 2992 15 1.7956972
# 保存模型： ./LSTM/stock.model2
# 2992 16 0.6171105
# 保存模型： ./LSTM/stock.model2
# 2992 17 2.7196221
# 保存模型： ./LSTM/stock.model2
# 2992 18 5.181603
# 保存模型： ./LSTM/stock.model2
# 2992 19 7.5454264
# 保存模型： ./LSTM/stock.model2
# 2992 20 2.6698482
# 保存模型： ./LSTM/stock.model2
# 2992 21 9.59903
# 保存模型： ./LSTM/stock.model2
# 2992 22 3.937115
# 保存模型： ./LSTM/stock.model2
# 2992 23 3.537264
# 保存模型： ./LSTM/stock.model2
# 2992 24 1.2849152
# 保存模型： ./LSTM/stock.model2
# 2992 25 0.75486356
# 保存模型： ./LSTM/stock.model2
# 2992 26 1.4096581
# 保存模型： ./LSTM/stock.model2
# 2992 27 3.4065125
# 保存模型： ./LSTM/stock.model2
# 2992 28 5.865748
# 保存模型： ./LSTM/stock.model2
# 2992 29 2.8805707
# 保存模型： ./LSTM/stock.model2
# 2992 30 4.6689396
# 保存模型： ./LSTM/stock.model2
# 2992 31 5.232749
# 保存模型： ./LSTM/stock.model2
# 2992 32 2.4484468
# 保存模型： ./LSTM/stock.model2
# 2992 33 3.2133691
# 保存模型： ./LSTM/stock.model2
# 2992 34 3.251103
# 保存模型： ./LSTM/stock.model2
# 2992 35 2.9023774
# 保存模型： ./LSTM/stock.model2
# 2992 36 5.546466
# 保存模型： ./LSTM/stock.model2
# 2992 37 5.2743425
# 保存模型： ./LSTM/stock.model2
# 2993 0 89.13837
# 保存模型： ./LSTM/stock.model2
# 2993 1 86.41381
# 保存模型： ./LSTM/stock.model2
# 2993 2 97.1082
# 保存模型： ./LSTM/stock.model2
# 2993 3 78.29942
# 保存模型： ./LSTM/stock.model2
# 2993 4 47.99167
# 保存模型： ./LSTM/stock.model2
# 2993 5 43.949924
# 保存模型： ./LSTM/stock.model2
# 2993 6 38.122154
# 保存模型： ./LSTM/stock.model2
# 2993 7 33.182343
# 保存模型： ./LSTM/stock.model2
# 2993 8 17.658957
# 保存模型： ./LSTM/stock.model2
# 2993 9 11.559691
# 保存模型： ./LSTM/stock.model2
# 2993 10 6.892552
# 保存模型： ./LSTM/stock.model2
# 2993 11 3.4865649
# 保存模型： ./LSTM/stock.model2
# 2993 12 1.0685527
# 保存模型： ./LSTM/stock.model2
# 2993 13 1.5051241
# 保存模型： ./LSTM/stock.model2
# 2993 14 2.354676
# 保存模型： ./LSTM/stock.model2
# 2993 15 2.0022066
# 保存模型： ./LSTM/stock.model2
# 2993 16 1.0892571
# 保存模型： ./LSTM/stock.model2
# 2993 17 3.6114364
# 保存模型： ./LSTM/stock.model2
# 2993 18 7.4196663
# 保存模型： ./LSTM/stock.model2
# 2993 19 6.1443596
# 保存模型： ./LSTM/stock.model2
# 2993 20 1.6032172
# 保存模型： ./LSTM/stock.model2
# 2993 21 7.8125463
# 保存模型： ./LSTM/stock.model2
# 2993 22 5.8148
# 保存模型： ./LSTM/stock.model2
# 2993 23 3.706806
# 保存模型： ./LSTM/stock.model2
# 2993 24 1.8112603
# 保存模型： ./LSTM/stock.model2
# 2993 25 1.2440574
# 保存模型： ./LSTM/stock.model2
# 2993 26 2.013
# 保存模型： ./LSTM/stock.model2
# 2993 27 3.8067012
# 保存模型： ./LSTM/stock.model2
# 2993 28 4.7049065
# 保存模型： ./LSTM/stock.model2
# 2993 29 4.251963
# 保存模型： ./LSTM/stock.model2
# 2993 30 4.608828
# 保存模型： ./LSTM/stock.model2
# 2993 31 5.1057506
# 保存模型： ./LSTM/stock.model2
# 2993 32 2.472435
# 保存模型： ./LSTM/stock.model2
# 2993 33 3.4853964
# 保存模型： ./LSTM/stock.model2
# 2993 34 3.0388978
# 保存模型： ./LSTM/stock.model2
# 2993 35 3.1769032
# 保存模型： ./LSTM/stock.model2
# 2993 36 4.873357
# 保存模型： ./LSTM/stock.model2
# 2993 37 6.178828
# 保存模型： ./LSTM/stock.model2
# 2994 0 106.00583
# 保存模型： ./LSTM/stock.model2
# 2994 1 139.45549
# 保存模型： ./LSTM/stock.model2
# 2994 2 98.25793
# 保存模型： ./LSTM/stock.model2
# 2994 3 33.257835
# 保存模型： ./LSTM/stock.model2
# 2994 4 22.320978
# 保存模型： ./LSTM/stock.model2
# 2994 5 36.775047
# 保存模型： ./LSTM/stock.model2
# 2994 6 30.782415
# 保存模型： ./LSTM/stock.model2
# 2994 7 33.63785
# 保存模型： ./LSTM/stock.model2
# 2994 8 20.537676
# 保存模型： ./LSTM/stock.model2
# 2994 9 16.006199
# 保存模型： ./LSTM/stock.model2
# 2994 10 7.447081
# 保存模型： ./LSTM/stock.model2
# 2994 11 6.3084636
# 保存模型： ./LSTM/stock.model2
# 2994 12 1.5694857
# 保存模型： ./LSTM/stock.model2
# 2994 13 1.7452266
# 保存模型： ./LSTM/stock.model2
# 2994 14 3.4623787
# 保存模型： ./LSTM/stock.model2
# 2994 15 1.778073
# 保存模型： ./LSTM/stock.model2
# 2994 16 0.68701714
# 保存模型： ./LSTM/stock.model2
# 2994 17 3.1393046
# 保存模型： ./LSTM/stock.model2
# 2994 18 8.367043
# 保存模型： ./LSTM/stock.model2
# 2994 19 7.550607
# 保存模型： ./LSTM/stock.model2
# 2994 20 3.229961
# 保存模型： ./LSTM/stock.model2
# 2994 21 7.5419164
# 保存模型： ./LSTM/stock.model2
# 2994 22 4.690452
# 保存模型： ./LSTM/stock.model2
# 2994 23 3.4914417
# 保存模型： ./LSTM/stock.model2
# 2994 24 1.1722467
# 保存模型： ./LSTM/stock.model2
# 2994 25 0.87385803
# 保存模型： ./LSTM/stock.model2
# 2994 26 1.4715449
# 保存模型： ./LSTM/stock.model2
# 2994 27 3.741117
# 保存模型： ./LSTM/stock.model2
# 2994 28 5.0066648
# 保存模型： ./LSTM/stock.model2
# 2994 29 3.7672591
# 保存模型： ./LSTM/stock.model2
# 2994 30 5.687602
# 保存模型： ./LSTM/stock.model2
# 2994 31 5.229372
# 保存模型： ./LSTM/stock.model2
# 2994 32 3.0105789
# 保存模型： ./LSTM/stock.model2
# 2994 33 2.9385748
# 保存模型： ./LSTM/stock.model2
# 2994 34 2.8388147
# 保存模型： ./LSTM/stock.model2
# 2994 35 2.7571
# 保存模型： ./LSTM/stock.model2
# 2994 36 4.775935
# 保存模型： ./LSTM/stock.model2
# 2994 37 6.0988836
# 保存模型： ./LSTM/stock.model2
# 2995 0 63.11972
# 保存模型： ./LSTM/stock.model2
# 2995 1 76.147865
# 保存模型： ./LSTM/stock.model2
# 2995 2 68.656265
# 保存模型： ./LSTM/stock.model2
# 2995 3 59.654972
# 保存模型： ./LSTM/stock.model2
# 2995 4 45.144226
# 保存模型： ./LSTM/stock.model2
# 2995 5 35.675724
# 保存模型： ./LSTM/stock.model2
# 2995 6 67.02507
# 保存模型： ./LSTM/stock.model2
# 2995 7 24.494335
# 保存模型： ./LSTM/stock.model2
# 2995 8 26.754261
# 保存模型： ./LSTM/stock.model2
# 2995 9 12.145222
# 保存模型： ./LSTM/stock.model2
# 2995 10 7.523281
# 保存模型： ./LSTM/stock.model2
# 2995 11 3.8897758
# 保存模型： ./LSTM/stock.model2
# 2995 12 1.5150521
# 保存模型： ./LSTM/stock.model2
# 2995 13 1.9546627
# 保存模型： ./LSTM/stock.model2
# 2995 14 2.5760176
# 保存模型： ./LSTM/stock.model2
# 2995 15 1.8531816
# 保存模型： ./LSTM/stock.model2
# 2995 16 1.1936531
# 保存模型： ./LSTM/stock.model2
# 2995 17 2.8457084
# 保存模型： ./LSTM/stock.model2
# 2995 18 6.6386123
# 保存模型： ./LSTM/stock.model2
# 2995 19 5.9568157
# 保存模型： ./LSTM/stock.model2
# 2995 20 2.1309462
# 保存模型： ./LSTM/stock.model2
# 2995 21 7.5949097
# 保存模型： ./LSTM/stock.model2
# 2995 22 6.690849
# 保存模型： ./LSTM/stock.model2
# 2995 23 3.7113976
# 保存模型： ./LSTM/stock.model2
# 2995 24 1.8934658
# 保存模型： ./LSTM/stock.model2
# 2995 25 1.3245008
# 保存模型： ./LSTM/stock.model2
# 2995 26 2.3663366
# 保存模型： ./LSTM/stock.model2
# 2995 27 4.5333242
# 保存模型： ./LSTM/stock.model2
# 2995 28 4.8280425
# 保存模型： ./LSTM/stock.model2
# 2995 29 3.548998
# 保存模型： ./LSTM/stock.model2
# 2995 30 3.306479
# 保存模型： ./LSTM/stock.model2
# 2995 31 4.967737
# 保存模型： ./LSTM/stock.model2
# 2995 32 3.5925326
# 保存模型： ./LSTM/stock.model2
# 2995 33 4.079772
# 保存模型： ./LSTM/stock.model2
# 2995 34 2.775812
# 保存模型： ./LSTM/stock.model2
# 2995 35 3.4961915
# 保存模型： ./LSTM/stock.model2
# 2995 36 5.9332075
# 保存模型： ./LSTM/stock.model2
# 2995 37 7.3148403
# 保存模型： ./LSTM/stock.model2
# 2996 0 104.17254
# 保存模型： ./LSTM/stock.model2
# 2996 1 152.43301
# 保存模型： ./LSTM/stock.model2
# 2996 2 72.443375
# 保存模型： ./LSTM/stock.model2
# 2996 3 26.64417
# 保存模型： ./LSTM/stock.model2
# 2996 4 24.931795
# 保存模型： ./LSTM/stock.model2
# 2996 5 39.8441
# 保存模型： ./LSTM/stock.model2
# 2996 6 35.030354
# 保存模型： ./LSTM/stock.model2
# 2996 7 27.72219
# 保存模型： ./LSTM/stock.model2
# 2996 8 13.712799
# 保存模型： ./LSTM/stock.model2
# 2996 9 14.009936
# 保存模型： ./LSTM/stock.model2
# 2996 10 7.9099536
# 保存模型： ./LSTM/stock.model2
# 2996 11 5.567479
# 保存模型： ./LSTM/stock.model2
# 2996 12 1.9210384
# 保存模型： ./LSTM/stock.model2
# 2996 13 1.6089996
# 保存模型： ./LSTM/stock.model2
# 2996 14 3.6417537
# 保存模型： ./LSTM/stock.model2
# 2996 15 1.6115608
# 保存模型： ./LSTM/stock.model2
# 2996 16 1.0501615
# 保存模型： ./LSTM/stock.model2
# 2996 17 2.5671477
# 保存模型： ./LSTM/stock.model2
# 2996 18 7.0553384
# 保存模型： ./LSTM/stock.model2
# 2996 19 7.787982
# 保存模型： ./LSTM/stock.model2
# 2996 20 2.1580484
# 保存模型： ./LSTM/stock.model2
# 2996 21 6.0101504
# 保存模型： ./LSTM/stock.model2
# 2996 22 6.4277267
# 保存模型： ./LSTM/stock.model2
# 2996 23 3.0012548
# 保存模型： ./LSTM/stock.model2
# 2996 24 1.3250791
# 保存模型： ./LSTM/stock.model2
# 2996 25 0.8430254
# 保存模型： ./LSTM/stock.model2
# 2996 26 1.3941202
# 保存模型： ./LSTM/stock.model2
# 2996 27 3.8097832
# 保存模型： ./LSTM/stock.model2
# 2996 28 4.677299
# 保存模型： ./LSTM/stock.model2
# 2996 29 4.174851
# 保存模型： ./LSTM/stock.model2
# 2996 30 3.918781
# 保存模型： ./LSTM/stock.model2
# 2996 31 5.1835036
# 保存模型： ./LSTM/stock.model2
# 2996 32 3.188014
# 保存模型： ./LSTM/stock.model2
# 2996 33 3.3076875
# 保存模型： ./LSTM/stock.model2
# 2996 34 2.427308
# 保存模型： ./LSTM/stock.model2
# 2996 35 3.093177
# 保存模型： ./LSTM/stock.model2
# 2996 36 4.857544
# 保存模型： ./LSTM/stock.model2
# 2996 37 4.903374
# 保存模型： ./LSTM/stock.model2
# 2997 0 91.11235
# 保存模型： ./LSTM/stock.model2
# 2997 1 57.68752
# 保存模型： ./LSTM/stock.model2
# 2997 2 79.02155
# 保存模型： ./LSTM/stock.model2
# 2997 3 48.502872
# 保存模型： ./LSTM/stock.model2
# 2997 4 43.548264
# 保存模型： ./LSTM/stock.model2
# 2997 5 53.8039
# 保存模型： ./LSTM/stock.model2
# 2997 6 41.236523
# 保存模型： ./LSTM/stock.model2
# 2997 7 26.974493
# 保存模型： ./LSTM/stock.model2
# 2997 8 23.994257
# 保存模型： ./LSTM/stock.model2
# 2997 9 10.285021
# 保存模型： ./LSTM/stock.model2
# 2997 10 6.6775637
# 保存模型： ./LSTM/stock.model2
# 2997 11 4.206905
# 保存模型： ./LSTM/stock.model2
# 2997 12 1.716809
# 保存模型： ./LSTM/stock.model2
# 2997 13 1.6932626
# 保存模型： ./LSTM/stock.model2
# 2997 14 2.594797
# 保存模型： ./LSTM/stock.model2
# 2997 15 2.4718108
# 保存模型： ./LSTM/stock.model2
# 2997 16 1.1602741
# 保存模型： ./LSTM/stock.model2
# 2997 17 3.0334988
# 保存模型： ./LSTM/stock.model2
# 2997 18 8.035684
# 保存模型： ./LSTM/stock.model2
# 2997 19 8.554984
# 保存模型： ./LSTM/stock.model2
# 2997 20 1.7648071
# 保存模型： ./LSTM/stock.model2
# 2997 21 6.3403325
# 保存模型： ./LSTM/stock.model2
# 2997 22 7.2512565
# 保存模型： ./LSTM/stock.model2
# 2997 23 3.7457032
# 保存模型： ./LSTM/stock.model2
# 2997 24 1.6815785
# 保存模型： ./LSTM/stock.model2
# 2997 25 1.3774737
# 保存模型： ./LSTM/stock.model2
# 2997 26 2.142944
# 保存模型： ./LSTM/stock.model2
# 2997 27 4.648689
# 保存模型： ./LSTM/stock.model2
# 2997 28 5.195245
# 保存模型： ./LSTM/stock.model2
# 2997 29 3.3515604
# 保存模型： ./LSTM/stock.model2
# 2997 30 4.415696
# 保存模型： ./LSTM/stock.model2
# 2997 31 6.0524197
# 保存模型： ./LSTM/stock.model2
# 2997 32 4.3389964
# 保存模型： ./LSTM/stock.model2
# 2997 33 4.7245717
# 保存模型： ./LSTM/stock.model2
# 2997 34 3.6383102
# 保存模型： ./LSTM/stock.model2
# 2997 35 3.7760713
# 保存模型： ./LSTM/stock.model2
# 2997 36 6.996512
# 保存模型： ./LSTM/stock.model2
# 2997 37 6.5078354
# 保存模型： ./LSTM/stock.model2
# 2998 0 105.84417
# 保存模型： ./LSTM/stock.model2
# 2998 1 110.26845
# 保存模型： ./LSTM/stock.model2
# 2998 2 85.294075
# 保存模型： ./LSTM/stock.model2
# 2998 3 32.127922
# 保存模型： ./LSTM/stock.model2
# 2998 4 20.122541
# 保存模型： ./LSTM/stock.model2
# 2998 5 28.461601
# 保存模型： ./LSTM/stock.model2
# 2998 6 27.260567
# 保存模型： ./LSTM/stock.model2
# 2998 7 28.527786
# 保存模型： ./LSTM/stock.model2
# 2998 8 12.669975
# 保存模型： ./LSTM/stock.model2
# 2998 9 12.443965
# 保存模型： ./LSTM/stock.model2
# 2998 10 7.810949
# 保存模型： ./LSTM/stock.model2
# 2998 11 6.2368484
# 保存模型： ./LSTM/stock.model2
# 2998 12 1.7230538
# 保存模型： ./LSTM/stock.model2
# 2998 13 1.5311568
# 保存模型： ./LSTM/stock.model2
# 2998 14 3.8638391
# 保存模型： ./LSTM/stock.model2
# 2998 15 1.9043492
# 保存模型： ./LSTM/stock.model2
# 2998 16 0.9587748
# 保存模型： ./LSTM/stock.model2
# 2998 17 2.939544
# 保存模型： ./LSTM/stock.model2
# 2998 18 6.205662
# 保存模型： ./LSTM/stock.model2
# 2998 19 7.1181884
# 保存模型： ./LSTM/stock.model2
# 2998 20 3.0876083
# 保存模型： ./LSTM/stock.model2
# 2998 21 7.661446
# 保存模型： ./LSTM/stock.model2
# 2998 22 5.0040803
# 保存模型： ./LSTM/stock.model2
# 2998 23 3.3868275
# 保存模型： ./LSTM/stock.model2
# 2998 24 1.2933637
# 保存模型： ./LSTM/stock.model2
# 2998 25 0.84393626
# 保存模型： ./LSTM/stock.model2
# 2998 26 1.4173334
# 保存模型： ./LSTM/stock.model2
# 2998 27 4.7688155
# 保存模型： ./LSTM/stock.model2
# 2998 28 5.307292
# 保存模型： ./LSTM/stock.model2
# 2998 29 3.7268498
# 保存模型： ./LSTM/stock.model2
# 2998 30 4.5136914
# 保存模型： ./LSTM/stock.model2
# 2998 31 4.566587
# 保存模型： ./LSTM/stock.model2
# 2998 32 2.8330252
# 保存模型： ./LSTM/stock.model2
# 2998 33 3.1842155
# 保存模型： ./LSTM/stock.model2
# 2998 34 2.6041102
# 保存模型： ./LSTM/stock.model2
# 2998 35 3.349996
# 保存模型： ./LSTM/stock.model2
# 2998 36 6.372585
# 保存模型： ./LSTM/stock.model2
# 2998 37 4.912546
# 保存模型： ./LSTM/stock.model2
# 2999 0 59.518932
# 保存模型： ./LSTM/stock.model2
# 2999 1 61.60974
# 保存模型： ./LSTM/stock.model2
# 2999 2 102.54826
# 保存模型： ./LSTM/stock.model2
# 2999 3 53.265778
# 保存模型： ./LSTM/stock.model2
# 2999 4 50.838303
# 保存模型： ./LSTM/stock.model2
# 2999 5 39.81323
# 保存模型： ./LSTM/stock.model2
# 2999 6 48.69897
# 保存模型： ./LSTM/stock.model2
# 2999 7 31.183931
# 保存模型： ./LSTM/stock.model2
# 2999 8 23.498995
# 保存模型： ./LSTM/stock.model2
# 2999 9 12.661092
# 保存模型： ./LSTM/stock.model2
# 2999 10 5.6505184
# 保存模型： ./LSTM/stock.model2
# 2999 11 3.1354768
# 保存模型： ./LSTM/stock.model2
# 2999 12 1.2745595
# 保存模型： ./LSTM/stock.model2
# 2999 13 1.8667626
# 保存模型： ./LSTM/stock.model2
# 2999 14 2.5167382
# 保存模型： ./LSTM/stock.model2
# 2999 15 1.8674219
# 保存模型： ./LSTM/stock.model2
# 2999 16 0.8890757
# 保存模型： ./LSTM/stock.model2
# 2999 17 2.9625056
# 保存模型： ./LSTM/stock.model2
# 2999 18 7.0108666
# 保存模型： ./LSTM/stock.model2
# 2999 19 6.5643644
# 保存模型： ./LSTM/stock.model2
# 2999 20 1.9721149
# 保存模型： ./LSTM/stock.model2
# 2999 21 7.128305
# 保存模型： ./LSTM/stock.model2
# 2999 22 6.349755
# 保存模型： ./LSTM/stock.model2
# 2999 23 4.043925
# 保存模型： ./LSTM/stock.model2
# 2999 24 2.0862148
# 保存模型： ./LSTM/stock.model2
# 2999 25 1.6612822
# 保存模型： ./LSTM/stock.model2
# 2999 26 2.383219
# 保存模型： ./LSTM/stock.model2
# 2999 27 3.7632399
# 保存模型： ./LSTM/stock.model2
# 2999 28 3.7650292
# 保存模型： ./LSTM/stock.model2
# 2999 29 2.8473606
# 保存模型： ./LSTM/stock.model2
# 2999 30 3.749063
# 保存模型： ./LSTM/stock.model2
# 2999 31 5.0245094
# 保存模型： ./LSTM/stock.model2
# 2999 32 3.148327
# 保存模型： ./LSTM/stock.model2
# 2999 33 3.5639002
# 保存模型： ./LSTM/stock.model2
# 2999 34 3.2248743
# 保存模型： ./LSTM/stock.model2
# 2999 35 3.7304428
# 保存模型： ./LSTM/stock.model2
# 2999 36 7.173357
# 保存模型： ./LSTM/stock.model2
# 2999 37 7.639827
# 保存模型： ./LSTM/stock.model2

# %%
#————————————————prediction————————————————————
def prediction():
    pred1,_=lstm(1,1,1)      
    saver=tf.train.Saver(tf.global_variables())
    with tf.Session() as sess:
        module_file = tf.train.latest_checkpoint(r'./LSTM')
        saver.restore(sess, module_file) 
        print(test_x)
        test_predict=[]
        
        for i in range(len(test_x)):
            prob=sess.run(pred1,feed_dict={X:[test_x[i]]})   
            predict=prob.reshape((-1))
            test_predict.extend(predict)
            
        
        plt.figure()
        plt.plot(list(range(len(test_predict))), test_predict, color='r')
        plt.plot(list(range(len(test_y))), test_y,  color='b')
        plt.show()
        
        acc = np.sum(np.abs(list(test_y[i] - test_predict[i] for i in range(len(test_y)))))/len(test_y)
        print(acc)
   

        c = {"real" : test_y,"predict" : test_predict}
        test = pd.DataFrame(c)
        #test=test.T
        print(test)
        
        
       
with tf.variable_scope('train',reuse=True):
    prediction()
# Out:
# Tensor("train_1/Reshape:0", shape=(?, 1), dtype=float32)
# Tensor("train_1/Relu:0", shape=(?, 10), dtype=float32)
# Tensor("train_1/Reshape_1:0", shape=(?, 1, 10), dtype=float32)
# <tf.Variable 'w_in:0' shape=(1, 10) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from ./LSTM/stock.model2
# [[[41.55]], [[41.7]], [[40.4]], [[37.6]], [[38.65]], [[39.7]], [[39.6]], [[39.5]], [[39.65]], [[39.25]], [[39.8]], [[41.0]], [[41.7]], [[41.75]], [[45.0]], [[44.4]], [[44.25]], [[43.8]], [[42.0]], [[42.5]], [[40.85]], [[40.0]], [[38.25]], [[39.75]], [[38.2]], [[39.8]], [[40.55]], [[40.2]], [[41.1]], [[41.85]]]
# 2.6665705108642572
#        real    predict
# 0    [41.7]  41.664726
# 1    [40.4]  41.762627
# 2    [37.6]  38.634190
# 3   [38.65]  34.934147
# 4    [39.7]  37.254429
# 5    [39.6]  38.489578
# 6    [39.5]  34.934147
# 7   [39.65]  38.049843
# 8   [39.25]  38.382183
# 9    [39.8]  37.591175
# 10   [41.0]  38.699478
# 11   [41.7]  40.799347
# 12  [41.75]  34.934147
# 13   [45.0]  39.862949
# 14   [44.4]  42.836765
# 15  [44.25]  44.628071
# 16   [43.8]  34.934147
# 17   [42.0]  34.934147
# 18   [42.5]  40.090950
# 19  [40.85]  40.547352
# 20   [40.0]  34.934147
# 21  [38.25]  39.100719
# 22  [39.75]  36.687607
# 23   [38.2]  38.044193
# 24   [39.8]  34.934147
# 25  [40.55]  38.089535
# 26   [40.2]  38.770500
# 27   [41.1]  34.934147
# 28  [41.85]  40.946301
# 29   [41.6]  41.951595
